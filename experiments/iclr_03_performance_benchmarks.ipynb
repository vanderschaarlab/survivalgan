# %%
import sys
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import synthcity.logger as log

from datasets import get_dataset

warnings.filterwarnings("ignore", category=FutureWarning)

log.remove()
warnings.filterwarnings("ignore")
log.add(sink=sys.stderr, level="DEBUG")

# %%
from pathlib import Path

import tabulate
from adjutorium.utils.metrics import generate_score, print_score
from synthcity.metrics.eval_performance import (PerformanceEvaluatorLinear,
                                                PerformanceEvaluatorMLP,
                                                PerformanceEvaluatorXGB)
from synthcity.plugins.core.dataloader import SurvivalAnalysisDataLoader
from synthcity.utils.serialization import (dataframe_hash, load_from_file,
                                           save_to_file)

log.remove()

datasets = [
    "aids",
    "cutract",
    "maggic",
    "seer",
]
methods = ["survival_gan", "ctgan", "nflow", "tvae", "privbayes", "adsgan"]

out_dir = Path("workspace")
headers = ["dataset"] + methods

results = {}
for ref_df in [
    "aids",
    "cutract",
    "maggic",
    "seer",
]:
    results[ref_df] = {}

    print("=======================")
    print("Evaluate ", ref_df)

    df, duration_col, event_col, time_horizons = get_dataset(ref_df)
    df_hash = dataframe_hash(df)

    real_dataloader = SurvivalAnalysisDataLoader(
        df,
        time_to_event_column=duration_col,
        target_column=event_col,
        time_horizons=time_horizons,
    )
    local_distance = [ref_df]
    for src_eval in [
        PerformanceEvaluatorMLP,
        PerformanceEvaluatorXGB,
        PerformanceEvaluatorLinear,
    ]:
        results[ref_df][src_eval.name()] = {
            "gt": {
                "c_index": [],
                "brier_score": [],
            }
        }

        for method in methods:
            results[ref_df][src_eval.name()][method] = {
                "c_index": [],
                "brier_score": [],
            }

            scores = []
            for seed in range(3):
                model_bkp = out_dir / f"{df_hash}_{method}_{seed}.bkp"
                syn_df = load_from_file(model_bkp)
                try:
                    syn_df = syn_df.dataframe()
                except BaseException as e:
                    pass

                syn_dataloader = SurvivalAnalysisDataLoader(
                    syn_df,
                    time_to_event_column=duration_col,
                    target_column=event_col,
                    time_horizons=time_horizons,
                )
                score = src_eval(task_type="survival_analysis").evaluate(
                    real_dataloader, syn_dataloader
                )
                print(ref_df, src_eval.name(), method, seed, score)
                results[ref_df][src_eval.name()]["gt"]["c_index"] = score["gt.c_index"]
                results[ref_df][src_eval.name()]["gt"]["brier_score"] = score[
                    "gt.brier_score"
                ]
                results[ref_df][src_eval.name()][method]["c_index"].append(
                    score["syn_ood.c_index"]
                )
                results[ref_df][src_eval.name()][method]["brier_score"].append(
                    score["syn_ood.brier_score"]
                )

results
# Out:
# =======================
# Evaluate  aids
# aids mlp survival_gan 0 {'gt.c_index': 0.7059304149697022, 'gt.brier_score': 0.06806232093352434, 'syn_id.c_index': 0.7213261019376978, 'syn_id.brier_score': 0.06819882377771379, 'syn_ood.c_index': 0.6454852592877075, 'syn_ood.brier_score': 0.07742694851561303}
# aids mlp survival_gan 1 {'gt.c_index': 0.7059304149697022, 'gt.brier_score': 0.06806232093352434, 'syn_id.c_index': 0.6549150597652914, 'syn_id.brier_score': 0.06818851102562119, 'syn_ood.c_index': 0.7165071752721839, 'syn_ood.brier_score': 0.07776424405215514}
# aids mlp survival_gan 2 {'gt.c_index': 0.7059304149697022, 'gt.brier_score': 0.06806232093352434, 'syn_id.c_index': 0.7161469010591421, 'syn_id.brier_score': 0.08966694941026791, 'syn_ood.c_index': 0.7644641382612013, 'syn_ood.brier_score': 0.07990441130531196}
# aids mlp ctgan 0 {'gt.c_index': 0.7059304149697022, 'gt.brier_score': 0.06806232093352434, 'syn_id.c_index': 0.5876149645646521, 'syn_id.brier_score': 0.06679559797339725, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# aids mlp ctgan 1 {'gt.c_index': 0.7059304149697022, 'gt.brier_score': 0.06806232093352434, 'syn_id.c_index': 0.4823442165819585, 'syn_id.brier_score': 0.06572764180769698, 'syn_ood.c_index': 0.520568649905171, 'syn_ood.brier_score': 0.07613622330571594}
# aids mlp ctgan 2 {'gt.c_index': 0.7059304149697022, 'gt.brier_score': 0.06806232093352434, 'syn_id.c_index': 0.31544197783192096, 'syn_id.brier_score': 0.12829031539214067, 'syn_ood.c_index': 0.5542162720615037, 'syn_ood.brier_score': 0.10876656241751877}
# aids mlp nflow 0 {'gt.c_index': 0.7059304149697022, 'gt.brier_score': 0.06806232093352434, 'syn_id.c_index': 0.42703951522670475, 'syn_id.brier_score': 0.12199268065742308, 'syn_ood.c_index': 0.3836290426816391, 'syn_ood.brier_score': 0.1360939367406394}
# aids mlp nflow 1 {'gt.c_index': 0.7059304149697022, 'gt.brier_score': 0.06806232093352434, 'syn_id.c_index': 0.32765451167105636, 'syn_id.brier_score': 0.14185473158203596, 'syn_ood.c_index': 0.37855223712306135, 'syn_ood.brier_score': 0.16071780684920026}
# aids mlp nflow 2 {'gt.c_index': 0.7059304149697022, 'gt.brier_score': 0.06806232093352434, 'syn_id.c_index': 0.42099494695666717, 'syn_id.brier_score': 0.11191742254235269, 'syn_ood.c_index': 0.5309118212646274, 'syn_ood.brier_score': 0.1273532349081433}
# aids mlp tvae 0 {'gt.c_index': 0.7059304149697022, 'gt.brier_score': 0.06806232093352434, 'syn_id.c_index': 0.0, 'syn_id.brier_score': 1.0, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# aids mlp tvae 1 {'gt.c_index': 0.7059304149697022, 'gt.brier_score': 0.06806232093352434, 'syn_id.c_index': 0.5144908598247837, 'syn_id.brier_score': 0.06825316361370086, 'syn_ood.c_index': 0.4973162193929452, 'syn_ood.brier_score': 0.07745913854287934}
# aids mlp tvae 2 {'gt.c_index': 0.7059304149697022, 'gt.brier_score': 0.06806232093352434, 'syn_id.c_index': 0.0, 'syn_id.brier_score': 1.0, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# aids mlp privbayes 0 {'gt.c_index': 0.7059304149697022, 'gt.brier_score': 0.06806232093352434, 'syn_id.c_index': 0.5306074944669945, 'syn_id.brier_score': 0.0680356854148327, 'syn_ood.c_index': 0.47586271354782933, 'syn_ood.brier_score': 0.07847409831109108}
# aids mlp privbayes 1 {'gt.c_index': 0.7059304149697022, 'gt.brier_score': 0.06806232093352434, 'syn_id.c_index': 0.5889217575241962, 'syn_id.brier_score': 0.080246886574098, 'syn_ood.c_index': 0.4173548020659998, 'syn_ood.brier_score': 0.09323820812133977}
# aids mlp privbayes 2 {'gt.c_index': 0.7059304149697022, 'gt.brier_score': 0.06806232093352434, 'syn_id.c_index': 0.35632496925349294, 'syn_id.brier_score': 0.06938236596216714, 'syn_ood.c_index': 0.2991700915100185, 'syn_ood.brier_score': 0.07883306714479758}
# aids mlp adsgan 0 {'gt.c_index': 0.7059304149697022, 'gt.brier_score': 0.06806232093352434, 'syn_id.c_index': 0.0, 'syn_id.brier_score': 1.0, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# aids mlp adsgan 1 {'gt.c_index': 0.7059304149697022, 'gt.brier_score': 0.06806232093352434, 'syn_id.c_index': 0.5560590458081266, 'syn_id.brier_score': 0.06564891643911962, 'syn_ood.c_index': 0.5985419306860772, 'syn_ood.brier_score': 0.07675083822459335}
# aids mlp adsgan 2 {'gt.c_index': 0.7059304149697022, 'gt.brier_score': 0.06806232093352434, 'syn_id.c_index': 0.0, 'syn_id.brier_score': 1.0, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# aids xgb survival_gan 0 {'gt.c_index': 0.7356953628118555, 'gt.brier_score': 0.062788404425297, 'syn_id.c_index': 0.7088925580210995, 'syn_id.brier_score': 0.062028514131082846, 'syn_ood.c_index': 0.5742303039522929, 'syn_ood.brier_score': 0.07134156171436111}
# aids xgb survival_gan 1 {'gt.c_index': 0.7356953628118555, 'gt.brier_score': 0.062788404425297, 'syn_id.c_index': 0.6811844911018308, 'syn_id.brier_score': 0.06223369466993212, 'syn_ood.c_index': 0.7854100648404208, 'syn_ood.brier_score': 0.06900873680903102}
# aids xgb survival_gan 2 {'gt.c_index': 0.7356953628118555, 'gt.brier_score': 0.062788404425297, 'syn_id.c_index': 0.7448176895356168, 'syn_id.brier_score': 0.06152026662639676, 'syn_ood.c_index': 0.7085975400715928, 'syn_ood.brier_score': 0.06915268699578814}
# aids xgb ctgan 0 {'gt.c_index': 0.7356953628118555, 'gt.brier_score': 0.062788404425297, 'syn_id.c_index': 0.6544014010218547, 'syn_id.brier_score': 0.06375809756788225, 'syn_ood.c_index': 0.6822746913277724, 'syn_ood.brier_score': 0.0721676595982021}
# aids xgb ctgan 1 {'gt.c_index': 0.7356953628118555, 'gt.brier_score': 0.062788404425297, 'syn_id.c_index': 0.44758617063686024, 'syn_id.brier_score': 0.06441617203754046, 'syn_ood.c_index': 0.4987423458317919, 'syn_ood.brier_score': 0.07289199673517642}
# aids xgb ctgan 2 {'gt.c_index': 0.7356953628118555, 'gt.brier_score': 0.062788404425297, 'syn_id.c_index': 0.6984116521988795, 'syn_id.brier_score': 0.06672079817186538, 'syn_ood.c_index': 0.7374737093767485, 'syn_ood.brier_score': 0.07400613390613633}
# aids xgb nflow 0 {'gt.c_index': 0.7356953628118555, 'gt.brier_score': 0.062788404425297, 'syn_id.c_index': 0.44005994899311035, 'syn_id.brier_score': 0.08943565540800984, 'syn_ood.c_index': 0.46994320089725, 'syn_ood.brier_score': 0.09653666803379451}
# aids xgb nflow 1 {'gt.c_index': 0.7356953628118555, 'gt.brier_score': 0.062788404425297, 'syn_id.c_index': 0.5058795347365108, 'syn_id.brier_score': 0.14112113260118145, 'syn_ood.c_index': 0.594376683161613, 'syn_ood.brier_score': 0.14253265702892295}
# aids xgb nflow 2 {'gt.c_index': 0.7356953628118555, 'gt.brier_score': 0.062788404425297, 'syn_id.c_index': 0.5193084563368519, 'syn_id.brier_score': 0.09075797524480896, 'syn_ood.c_index': 0.44862952170621034, 'syn_ood.brier_score': 0.09818776283163667}
# aids xgb tvae 0 {'gt.c_index': 0.7356953628118555, 'gt.brier_score': 0.062788404425297, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.06830532240128447, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.07746034739915574}
# aids xgb tvae 1 {'gt.c_index': 0.7356953628118555, 'gt.brier_score': 0.062788404425297, 'syn_id.c_index': 0.722557929077257, 'syn_id.brier_score': 0.0681678581972259, 'syn_ood.c_index': 0.6885742237330555, 'syn_ood.brier_score': 0.0773043198558032}
# aids xgb tvae 2 {'gt.c_index': 0.7356953628118555, 'gt.brier_score': 0.062788404425297, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.06817537611088904, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.0773128618326687}
# aids xgb privbayes 0 {'gt.c_index': 0.7356953628118555, 'gt.brier_score': 0.062788404425297, 'syn_id.c_index': 0.5724706149312274, 'syn_id.brier_score': 0.06621447239558427, 'syn_ood.c_index': 0.5888151534188154, 'syn_ood.brier_score': 0.0752125027563393}
# aids xgb privbayes 1 {'gt.c_index': 0.7356953628118555, 'gt.brier_score': 0.062788404425297, 'syn_id.c_index': 0.5313019067359338, 'syn_id.brier_score': 0.06332101478155773, 'syn_ood.c_index': 0.4782561856210427, 'syn_ood.brier_score': 0.07169927381484396}
# aids xgb privbayes 2 {'gt.c_index': 0.7356953628118555, 'gt.brier_score': 0.062788404425297, 'syn_id.c_index': 0.4613754456550203, 'syn_id.brier_score': 0.06376250663964186, 'syn_ood.c_index': 0.5732327893991209, 'syn_ood.brier_score': 0.07228436595620757}
# aids xgb adsgan 0 {'gt.c_index': 0.7356953628118555, 'gt.brier_score': 0.062788404425297, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.06830532240128447, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.07746034739915574}
# aids xgb adsgan 1 {'gt.c_index': 0.7356953628118555, 'gt.brier_score': 0.062788404425297, 'syn_id.c_index': 0.5548974502875726, 'syn_id.brier_score': 0.06415418623119011, 'syn_ood.c_index': 0.6940310329823038, 'syn_ood.brier_score': 0.0727556481660794}
# aids xgb adsgan 2 {'gt.c_index': 0.7356953628118555, 'gt.brier_score': 0.062788404425297, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.06830532240128447, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.07746034739915574}
# aids linear_model survival_gan 0 {'gt.c_index': 0.7376085764258152, 'gt.brier_score': 0.061707863206065416, 'syn_id.c_index': 0.0, 'syn_id.brier_score': 1.0, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# aids linear_model survival_gan 1 {'gt.c_index': 0.7376085764258152, 'gt.brier_score': 0.061707863206065416, 'syn_id.c_index': 0.0, 'syn_id.brier_score': 1.0, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# aids linear_model survival_gan 2 {'gt.c_index': 0.7376085764258152, 'gt.brier_score': 0.061707863206065416, 'syn_id.c_index': 0.0, 'syn_id.brier_score': 1.0, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# aids linear_model ctgan 0 {'gt.c_index': 0.7376085764258152, 'gt.brier_score': 0.061707863206065416, 'syn_id.c_index': 0.5233278400318319, 'syn_id.brier_score': 0.06451964372630864, 'syn_ood.c_index': 0.6949089269268556, 'syn_ood.brier_score': 0.0711931786732762}
# aids linear_model ctgan 1 {'gt.c_index': 0.7376085764258152, 'gt.brier_score': 0.061707863206065416, 'syn_id.c_index': 0.36051652263431994, 'syn_id.brier_score': 0.0661356685335258, 'syn_ood.c_index': 0.45723162100221026, 'syn_ood.brier_score': 0.07391699898006086}
# aids linear_model ctgan 2 {'gt.c_index': 0.7376085764258152, 'gt.brier_score': 0.061707863206065416, 'syn_id.c_index': 0.6923749300958288, 'syn_id.brier_score': 0.06555325944220294, 'syn_ood.c_index': 0.7866488639578796, 'syn_ood.brier_score': 0.06988575971496876}
# aids linear_model nflow 0 {'gt.c_index': 0.7376085764258152, 'gt.brier_score': 0.061707863206065416, 'syn_id.c_index': 0.7111972551791435, 'syn_id.brier_score': 0.08400522462256248, 'syn_ood.c_index': 0.5648951840565446, 'syn_ood.brier_score': 0.0913250877813039}
# aids linear_model nflow 1 {'gt.c_index': 0.7376085764258152, 'gt.brier_score': 0.061707863206065416, 'syn_id.c_index': 0.46875908804779165, 'syn_id.brier_score': 0.12312687607365998, 'syn_ood.c_index': 0.48358208181378104, 'syn_ood.brier_score': 0.12747251100036605}
# aids linear_model nflow 2 {'gt.c_index': 0.7376085764258152, 'gt.brier_score': 0.061707863206065416, 'syn_id.c_index': 0.5732028625179967, 'syn_id.brier_score': 0.10730371297924728, 'syn_ood.c_index': 0.46960948352234677, 'syn_ood.brier_score': 0.11552923188934193}
# aids linear_model tvae 0 {'gt.c_index': 0.7376085764258152, 'gt.brier_score': 0.061707863206065416, 'syn_id.c_index': 0.0, 'syn_id.brier_score': 1.0, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# aids linear_model tvae 1 {'gt.c_index': 0.7376085764258152, 'gt.brier_score': 0.061707863206065416, 'syn_id.c_index': 0.5514839032474682, 'syn_id.brier_score': 0.08175408291463532, 'syn_ood.c_index': 0.5136704390235118, 'syn_ood.brier_score': 0.09986260268150948}
# aids linear_model tvae 2 {'gt.c_index': 0.7376085764258152, 'gt.brier_score': 0.061707863206065416, 'syn_id.c_index': 0.5788263586069223, 'syn_id.brier_score': 0.07854043219537897, 'syn_ood.c_index': 0.49570821101240287, 'syn_ood.brier_score': 0.10206638969837839}
# aids linear_model privbayes 0 {'gt.c_index': 0.7376085764258152, 'gt.brier_score': 0.061707863206065416, 'syn_id.c_index': 0.5237069255249613, 'syn_id.brier_score': 0.06597481318284311, 'syn_ood.c_index': 0.5756952632093969, 'syn_ood.brier_score': 0.0744624317655898}
# aids linear_model privbayes 1 {'gt.c_index': 0.7376085764258152, 'gt.brier_score': 0.061707863206065416, 'syn_id.c_index': 0.5907615842119934, 'syn_id.brier_score': 0.06288612404153006, 'syn_ood.c_index': 0.5276712033890112, 'syn_ood.brier_score': 0.07174982366218323}
# aids linear_model privbayes 2 {'gt.c_index': 0.7376085764258152, 'gt.brier_score': 0.061707863206065416, 'syn_id.c_index': 0.33948314448592126, 'syn_id.brier_score': 0.06613413091353575, 'syn_ood.c_index': 0.5092327753601479, 'syn_ood.brier_score': 0.07360596121188029}
# aids linear_model adsgan 0 {'gt.c_index': 0.7376085764258152, 'gt.brier_score': 0.061707863206065416, 'syn_id.c_index': 0.0, 'syn_id.brier_score': 1.0, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# aids linear_model adsgan 1 {'gt.c_index': 0.7376085764258152, 'gt.brier_score': 0.061707863206065416, 'syn_id.c_index': 0.4455689034938513, 'syn_id.brier_score': 0.13767593749865936, 'syn_ood.c_index': 0.5181922792673933, 'syn_ood.brier_score': 0.174300646655429}
# aids linear_model adsgan 2 {'gt.c_index': 0.7376085764258152, 'gt.brier_score': 0.061707863206065416, 'syn_id.c_index': 0.0, 'syn_id.brier_score': 1.0, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# =======================
# Evaluate  cutract
# cutract mlp survival_gan 0 {'gt.c_index': 0.7227856874466392, 'gt.brier_score': 0.09078878664723468, 'syn_id.c_index': 0.6993704247414504, 'syn_id.brier_score': 0.09330547783166783, 'syn_ood.c_index': 0.6773662560026695, 'syn_ood.brier_score': 0.09294071269302889}
# cutract mlp survival_gan 1 {'gt.c_index': 0.7227856874466392, 'gt.brier_score': 0.09078878664723468, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.09983924807854304, 'syn_ood.c_index': 0.7745746052534509, 'syn_ood.brier_score': 0.08433732524161704}
# cutract mlp survival_gan 2 {'gt.c_index': 0.7227856874466392, 'gt.brier_score': 0.09078878664723468, 'syn_id.c_index': 0.7984934437588945, 'syn_id.brier_score': 0.09093075652740061, 'syn_ood.c_index': 0.7781613895561756, 'syn_ood.brier_score': 0.10017100712450633}
# cutract mlp ctgan 0 {'gt.c_index': 0.7227856874466392, 'gt.brier_score': 0.09078878664723468, 'syn_id.c_index': 0.7959520880770041, 'syn_id.brier_score': 0.16775249071453444, 'syn_ood.c_index': 0.7553184846865162, 'syn_ood.brier_score': 0.1849173173231573}
# cutract mlp ctgan 1 {'gt.c_index': 0.7227856874466392, 'gt.brier_score': 0.09078878664723468, 'syn_id.c_index': 0.7012475926951557, 'syn_id.brier_score': 0.23557166878759894, 'syn_ood.c_index': 0.6777539893172868, 'syn_ood.brier_score': 0.23579553681046647}
# cutract mlp ctgan 2 {'gt.c_index': 0.7227856874466392, 'gt.brier_score': 0.09078878664723468, 'syn_id.c_index': 0.7952237452968512, 'syn_id.brier_score': 0.18644685290042226, 'syn_ood.c_index': 0.7390306737034017, 'syn_ood.brier_score': 0.18296172823834211}
# cutract mlp nflow 0 {'gt.c_index': 0.7227856874466392, 'gt.brier_score': 0.09078878664723468, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.20501948449295226, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.2118141694051856}
# cutract mlp nflow 1 {'gt.c_index': 0.7227856874466392, 'gt.brier_score': 0.09078878664723468, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.20351642470324408, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.21303283198093467}
# cutract mlp nflow 2 {'gt.c_index': 0.7227856874466392, 'gt.brier_score': 0.09078878664723468, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.22159933986696786, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.21931965645569998}
# cutract mlp tvae 0 {'gt.c_index': 0.7227856874466392, 'gt.brier_score': 0.09078878664723468, 'syn_id.c_index': 0.6898416613393854, 'syn_id.brier_score': 0.1277130278634123, 'syn_ood.c_index': 0.6672435193952179, 'syn_ood.brier_score': 0.13643659037389988}
# cutract mlp tvae 1 {'gt.c_index': 0.7227856874466392, 'gt.brier_score': 0.09078878664723468, 'syn_id.c_index': 0.6834315593194039, 'syn_id.brier_score': 0.135655149596587, 'syn_ood.c_index': 0.6501148589004849, 'syn_ood.brier_score': 0.1334711128785412}
# cutract mlp tvae 2 {'gt.c_index': 0.7227856874466392, 'gt.brier_score': 0.09078878664723468, 'syn_id.c_index': 0.7185165192058736, 'syn_id.brier_score': 0.14414079441201613, 'syn_ood.c_index': 0.6103256770969473, 'syn_ood.brier_score': 0.16894916327383427}
# cutract mlp privbayes 0 {'gt.c_index': 0.7227856874466392, 'gt.brier_score': 0.09078878664723468, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.10024323852283967, 'syn_ood.c_index': 0.5011914114529299, 'syn_ood.brier_score': 0.09919928763334858}
# cutract mlp privbayes 1 {'gt.c_index': 0.7227856874466392, 'gt.brier_score': 0.09078878664723468, 'syn_id.c_index': 0.4619395720003398, 'syn_id.brier_score': 0.10061016733330919, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.09969794997165378}
# cutract mlp privbayes 2 {'gt.c_index': 0.7227856874466392, 'gt.brier_score': 0.09078878664723468, 'syn_id.c_index': 0.26939454929372303, 'syn_id.brier_score': 0.10746221162381354, 'syn_ood.c_index': 0.4985786034674285, 'syn_ood.brier_score': 0.0995445068894776}
# cutract mlp adsgan 0 {'gt.c_index': 0.7227856874466392, 'gt.brier_score': 0.09078878664723468, 'syn_id.c_index': 0.654742422040731, 'syn_id.brier_score': 0.11613096311513926, 'syn_ood.c_index': 0.6219788013585114, 'syn_ood.brier_score': 0.11203897652360846}
# cutract mlp adsgan 1 {'gt.c_index': 0.7227856874466392, 'gt.brier_score': 0.09078878664723468, 'syn_id.c_index': 0.0, 'syn_id.brier_score': 1.0, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# cutract mlp adsgan 2 {'gt.c_index': 0.7227856874466392, 'gt.brier_score': 0.09078878664723468, 'syn_id.c_index': 0.6206428751080325, 'syn_id.brier_score': 0.10015124673101594, 'syn_ood.c_index': 0.5566569436601775, 'syn_ood.brier_score': 0.10351229775096223}
# cutract xgb survival_gan 0 {'gt.c_index': 0.8319374581013449, 'gt.brier_score': 0.08457689286909124, 'syn_id.c_index': 0.8024119292428834, 'syn_id.brier_score': 0.08258289747666929, 'syn_ood.c_index': 0.7741866546777638, 'syn_ood.brier_score': 0.08556463616200416}
# cutract xgb survival_gan 1 {'gt.c_index': 0.8319374581013449, 'gt.brier_score': 0.08457689286909124, 'syn_id.c_index': 0.8140043784276072, 'syn_id.brier_score': 0.08371552721297336, 'syn_ood.c_index': 0.7804397937915969, 'syn_ood.brier_score': 0.08799037954154254}
# cutract xgb survival_gan 2 {'gt.c_index': 0.8319374581013449, 'gt.brier_score': 0.08457689286909124, 'syn_id.c_index': 0.8135992177922532, 'syn_id.brier_score': 0.08176268690201109, 'syn_ood.c_index': 0.7746854689867586, 'syn_ood.brier_score': 0.0857674646153521}
# cutract xgb ctgan 0 {'gt.c_index': 0.8319374581013449, 'gt.brier_score': 0.08457689286909124, 'syn_id.c_index': 0.8035643474266708, 'syn_id.brier_score': 0.17846161907409244, 'syn_ood.c_index': 0.7695774796569266, 'syn_ood.brier_score': 0.19355249482568615}
# cutract xgb ctgan 1 {'gt.c_index': 0.8319374581013449, 'gt.brier_score': 0.08457689286909124, 'syn_id.c_index': 0.8057052389503524, 'syn_id.brier_score': 0.21773532319842973, 'syn_ood.c_index': 0.775619153193384, 'syn_ood.brier_score': 0.2291775444741634}
# cutract xgb ctgan 2 {'gt.c_index': 0.8319374581013449, 'gt.brier_score': 0.08457689286909124, 'syn_id.c_index': 0.8181042950778908, 'syn_id.brier_score': 0.18875720314947494, 'syn_ood.c_index': 0.7781166464936881, 'syn_ood.brier_score': 0.2019013182753212}
# cutract xgb nflow 0 {'gt.c_index': 0.8319374581013449, 'gt.brier_score': 0.08457689286909124, 'syn_id.c_index': 0.7129111550760442, 'syn_id.brier_score': 0.19304094298018915, 'syn_ood.c_index': 0.6836882506780282, 'syn_ood.brier_score': 0.19911975079772234}
# cutract xgb nflow 1 {'gt.c_index': 0.8319374581013449, 'gt.brier_score': 0.08457689286909124, 'syn_id.c_index': 0.5490547097481887, 'syn_id.brier_score': 0.2075102726782081, 'syn_ood.c_index': 0.5049244070795614, 'syn_ood.brier_score': 0.2131364511566044}
# cutract xgb nflow 2 {'gt.c_index': 0.8319374581013449, 'gt.brier_score': 0.08457689286909124, 'syn_id.c_index': 0.5667922660889287, 'syn_id.brier_score': 0.20688613144565418, 'syn_ood.c_index': 0.5166486927515807, 'syn_ood.brier_score': 0.21327164845258859}
# cutract xgb tvae 0 {'gt.c_index': 0.8319374581013449, 'gt.brier_score': 0.08457689286909124, 'syn_id.c_index': 0.7503291814492848, 'syn_id.brier_score': 0.10024814509971745, 'syn_ood.c_index': 0.7186431662866388, 'syn_ood.brier_score': 0.09965156765209891}
# cutract xgb tvae 1 {'gt.c_index': 0.8319374581013449, 'gt.brier_score': 0.08457689286909124, 'syn_id.c_index': 0.7776538481036251, 'syn_id.brier_score': 0.09612823462896636, 'syn_ood.c_index': 0.7422151554796939, 'syn_ood.brier_score': 0.09820782415698236}
# cutract xgb tvae 2 {'gt.c_index': 0.8319374581013449, 'gt.brier_score': 0.08457689286909124, 'syn_id.c_index': 0.7974382639875023, 'syn_id.brier_score': 0.09208069116159996, 'syn_ood.c_index': 0.7627922954211982, 'syn_ood.brier_score': 0.09525052497309039}
# cutract xgb privbayes 0 {'gt.c_index': 0.8319374581013449, 'gt.brier_score': 0.08457689286909124, 'syn_id.c_index': 0.46746970397689563, 'syn_id.brier_score': 0.09981764376714637, 'syn_ood.c_index': 0.4845736296490728, 'syn_ood.brier_score': 0.09933357859454749}
# cutract xgb privbayes 1 {'gt.c_index': 0.8319374581013449, 'gt.brier_score': 0.08457689286909124, 'syn_id.c_index': 0.396389364409637, 'syn_id.brier_score': 0.10141996958667793, 'syn_ood.c_index': 0.4075450577243777, 'syn_ood.brier_score': 0.10075102540197052}
# cutract xgb privbayes 2 {'gt.c_index': 0.8319374581013449, 'gt.brier_score': 0.08457689286909124, 'syn_id.c_index': 0.6352708809104511, 'syn_id.brier_score': 0.09926812519375372, 'syn_ood.c_index': 0.586645728190701, 'syn_ood.brier_score': 0.09879764689271786}
# cutract xgb adsgan 0 {'gt.c_index': 0.8319374581013449, 'gt.brier_score': 0.08457689286909124, 'syn_id.c_index': 0.7311230589126194, 'syn_id.brier_score': 0.1166844310318174, 'syn_ood.c_index': 0.711142646483426, 'syn_ood.brier_score': 0.11389588655609607}
# cutract xgb adsgan 1 {'gt.c_index': 0.8319374581013449, 'gt.brier_score': 0.08457689286909124, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.11750097155150994, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.11468457957758581}
# cutract xgb adsgan 2 {'gt.c_index': 0.8319374581013449, 'gt.brier_score': 0.08457689286909124, 'syn_id.c_index': 0.6158550952960392, 'syn_id.brier_score': 0.11352721654964408, 'syn_ood.c_index': 0.587557517681081, 'syn_ood.brier_score': 0.11116755994790765}
# cutract linear_model survival_gan 0 {'gt.c_index': 0.8098309079742018, 'gt.brier_score': 0.07536036182071539, 'syn_id.c_index': 0.7944895147058469, 'syn_id.brier_score': 0.07574605280612448, 'syn_ood.c_index': 0.7626953767923544, 'syn_ood.brier_score': 0.08435359446666808}
# cutract linear_model survival_gan 1 {'gt.c_index': 0.8098309079742018, 'gt.brier_score': 0.07536036182071539, 'syn_id.c_index': 0.8012605247697286, 'syn_id.brier_score': 0.07828413832437754, 'syn_ood.c_index': 0.7568697049687904, 'syn_ood.brier_score': 0.0870116494443915}
# cutract linear_model survival_gan 2 {'gt.c_index': 0.8098309079742018, 'gt.brier_score': 0.07536036182071539, 'syn_id.c_index': 0.8087741715962581, 'syn_id.brier_score': 0.09581397133039615, 'syn_ood.c_index': 0.7687297248123496, 'syn_ood.brier_score': 0.10819228259054055}
# cutract linear_model ctgan 0 {'gt.c_index': 0.8098309079742018, 'gt.brier_score': 0.07536036182071539, 'syn_id.c_index': 0.7976123629288813, 'syn_id.brier_score': 0.16112846550197069, 'syn_ood.c_index': 0.7586253153808049, 'syn_ood.brier_score': 0.1686652101277557}
# cutract linear_model ctgan 1 {'gt.c_index': 0.8098309079742018, 'gt.brier_score': 0.07536036182071539, 'syn_id.c_index': 0.8073633392249625, 'syn_id.brier_score': 0.2032599226008458, 'syn_ood.c_index': 0.7676091861839117, 'syn_ood.brier_score': 0.21098839351746976}
# cutract linear_model ctgan 2 {'gt.c_index': 0.8098309079742018, 'gt.brier_score': 0.07536036182071539, 'syn_id.c_index': 0.8087018009483685, 'syn_id.brier_score': 0.16374077187360953, 'syn_ood.c_index': 0.7680070547371444, 'syn_ood.brier_score': 0.17083589343851488}
# cutract linear_model nflow 0 {'gt.c_index': 0.8098309079742018, 'gt.brier_score': 0.07536036182071539, 'syn_id.c_index': 0.7801891115512842, 'syn_id.brier_score': 0.18722980555725674, 'syn_ood.c_index': 0.7246664538005613, 'syn_ood.brier_score': 0.19298591661162987}
# cutract linear_model nflow 1 {'gt.c_index': 0.8098309079742018, 'gt.brier_score': 0.07536036182071539, 'syn_id.c_index': 0.5971553374730291, 'syn_id.brier_score': 0.18978415597949003, 'syn_ood.c_index': 0.5830555439090589, 'syn_ood.brier_score': 0.19398797773963763}
# cutract linear_model nflow 2 {'gt.c_index': 0.8098309079742018, 'gt.brier_score': 0.07536036182071539, 'syn_id.c_index': 0.72339004190366, 'syn_id.brier_score': 0.20970909070178667, 'syn_ood.c_index': 0.6586605983597654, 'syn_ood.brier_score': 0.21662508718053938}
# cutract linear_model tvae 0 {'gt.c_index': 0.8098309079742018, 'gt.brier_score': 0.07536036182071539, 'syn_id.c_index': 0.8048561145935714, 'syn_id.brier_score': 0.1050467845474713, 'syn_ood.c_index': 0.7647022446718711, 'syn_ood.brier_score': 0.10632582258976275}
# cutract linear_model tvae 1 {'gt.c_index': 0.8098309079742018, 'gt.brier_score': 0.07536036182071539, 'syn_id.c_index': 0.7700488327083915, 'syn_id.brier_score': 0.10327005812510698, 'syn_ood.c_index': 0.7500175950992182, 'syn_ood.brier_score': 0.10316631787731234}
# cutract linear_model tvae 2 {'gt.c_index': 0.8098309079742018, 'gt.brier_score': 0.07536036182071539, 'syn_id.c_index': 0.8100327909328908, 'syn_id.brier_score': 0.09676265070903291, 'syn_ood.c_index': 0.7730655791592701, 'syn_ood.brier_score': 0.09992020036853022}
# cutract linear_model privbayes 0 {'gt.c_index': 0.8098309079742018, 'gt.brier_score': 0.07536036182071539, 'syn_id.c_index': 0.4521451716679654, 'syn_id.brier_score': 0.10001345156490031, 'syn_ood.c_index': 0.48398111402388005, 'syn_ood.brier_score': 0.0994239958937826}
# cutract linear_model privbayes 1 {'gt.c_index': 0.8098309079742018, 'gt.brier_score': 0.07536036182071539, 'syn_id.c_index': 0.3237453311315414, 'syn_id.brier_score': 0.10267225273108056, 'syn_ood.c_index': 0.33731524870343793, 'syn_ood.brier_score': 0.10190681977567288}
# cutract linear_model privbayes 2 {'gt.c_index': 0.8098309079742018, 'gt.brier_score': 0.07536036182071539, 'syn_id.c_index': 0.5009709628806079, 'syn_id.brier_score': 0.1000232771427625, 'syn_ood.c_index': 0.46263432096907015, 'syn_ood.brier_score': 0.0996153281745405}
# cutract linear_model adsgan 0 {'gt.c_index': 0.8098309079742018, 'gt.brier_score': 0.07536036182071539, 'syn_id.c_index': 0.7348571923592969, 'syn_id.brier_score': 0.11434967553222192, 'syn_ood.c_index': 0.7233637838538503, 'syn_ood.brier_score': 0.11152711481069337}
# cutract linear_model adsgan 1 {'gt.c_index': 0.8098309079742018, 'gt.brier_score': 0.07536036182071539, 'syn_id.c_index': 0.0, 'syn_id.brier_score': 1.0, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# cutract linear_model adsgan 2 {'gt.c_index': 0.8098309079742018, 'gt.brier_score': 0.07536036182071539, 'syn_id.c_index': 0.3959554104580649, 'syn_id.brier_score': 0.12314631153229318, 'syn_ood.c_index': 0.3924229936801327, 'syn_ood.brier_score': 0.11896602051966236}
# =======================
# Evaluate  maggic
# maggic mlp survival_gan 0 {'gt.c_index': 0.6351989261191153, 'gt.brier_score': 0.1679785580062451, 'syn_id.c_index': 0.5002146329454452, 'syn_id.brier_score': 0.18826437176211852, 'syn_ood.c_index': 0.5451663572193332, 'syn_ood.brier_score': 0.1847187674345568}
# maggic mlp survival_gan 1 {'gt.c_index': 0.6351989261191153, 'gt.brier_score': 0.1679785580062451, 'syn_id.c_index': 0.6130981574155442, 'syn_id.brier_score': 0.1815901546291789, 'syn_ood.c_index': 0.6132180676114923, 'syn_ood.brier_score': 0.1838610067650488}
# maggic mlp survival_gan 2 {'gt.c_index': 0.6351989261191153, 'gt.brier_score': 0.1679785580062451, 'syn_id.c_index': 0.6347608498294851, 'syn_id.brier_score': 0.1789614284000518, 'syn_ood.c_index': 0.6407541317291121, 'syn_ood.brier_score': 0.17898222405093908}
# maggic mlp ctgan 0 {'gt.c_index': 0.6351989261191153, 'gt.brier_score': 0.1679785580062451, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.19530325911248939, 'syn_ood.c_index': 0.4997565094398053, 'syn_ood.brier_score': 0.20289603605986942}
# maggic mlp ctgan 1 {'gt.c_index': 0.6351989261191153, 'gt.brier_score': 0.1679785580062451, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.1862180159279009, 'syn_ood.c_index': 0.5004247032471466, 'syn_ood.brier_score': 0.19245772797563043}
# maggic mlp ctgan 2 {'gt.c_index': 0.6351989261191153, 'gt.brier_score': 0.1679785580062451, 'syn_id.c_index': 0.49986940329060503, 'syn_id.brier_score': 0.18968280004120597, 'syn_ood.c_index': 0.49892071942860367, 'syn_ood.brier_score': 0.19649597639613162}
# maggic mlp nflow 0 {'gt.c_index': 0.6351989261191153, 'gt.brier_score': 0.1679785580062451, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.189488823859887, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.19279772197451106}
# maggic mlp nflow 1 {'gt.c_index': 0.6351989261191153, 'gt.brier_score': 0.1679785580062451, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.18801797192344827, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.1905426105930417}
# maggic mlp nflow 2 {'gt.c_index': 0.6351989261191153, 'gt.brier_score': 0.1679785580062451, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.19104491275675226, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.1940005379882294}
# maggic mlp tvae 0 {'gt.c_index': 0.6351989261191153, 'gt.brier_score': 0.1679785580062451, 'syn_id.c_index': 0.5391232487252405, 'syn_id.brier_score': 0.20720585339864006, 'syn_ood.c_index': 0.5413940319523554, 'syn_ood.brier_score': 0.2210225085691858}
# maggic mlp tvae 1 {'gt.c_index': 0.6351989261191153, 'gt.brier_score': 0.1679785580062451, 'syn_id.c_index': 0.534847754708124, 'syn_id.brier_score': 0.20710847859068168, 'syn_ood.c_index': 0.5536179448335039, 'syn_ood.brier_score': 0.21255836419563423}
# maggic mlp tvae 2 {'gt.c_index': 0.6351989261191153, 'gt.brier_score': 0.1679785580062451, 'syn_id.c_index': 0.5682153223482465, 'syn_id.brier_score': 0.22191022346943004, 'syn_ood.c_index': 0.5356216133258178, 'syn_ood.brier_score': 0.21067922115545704}
# maggic mlp privbayes 0 {'gt.c_index': 0.6351989261191153, 'gt.brier_score': 0.1679785580062451, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.2149202349339248, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.21609710425173811}
# maggic mlp privbayes 1 {'gt.c_index': 0.6351989261191153, 'gt.brier_score': 0.1679785580062451, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.2080137887238107, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.20754231534156667}
# maggic mlp privbayes 2 {'gt.c_index': 0.6351989261191153, 'gt.brier_score': 0.1679785580062451, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.20385653322783245, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.20696313974108368}
# maggic mlp adsgan 0 {'gt.c_index': 0.6351989261191153, 'gt.brier_score': 0.1679785580062451, 'syn_id.c_index': 0.47653736398329666, 'syn_id.brier_score': 0.2283734377893005, 'syn_ood.c_index': 0.5049834223015863, 'syn_ood.brier_score': 0.22621436388118185}
# maggic mlp adsgan 1 {'gt.c_index': 0.6351989261191153, 'gt.brier_score': 0.1679785580062451, 'syn_id.c_index': 0.5252009131917531, 'syn_id.brier_score': 0.19876566573525298, 'syn_ood.c_index': 0.5334826640220739, 'syn_ood.brier_score': 0.23016003082697867}
# maggic mlp adsgan 2 {'gt.c_index': 0.6351989261191153, 'gt.brier_score': 0.1679785580062451, 'syn_id.c_index': 0.5207514575630297, 'syn_id.brier_score': 0.2278723570240777, 'syn_ood.c_index': 0.5105364847317403, 'syn_ood.brier_score': 0.24244769043557493}
# maggic xgb survival_gan 0 {'gt.c_index': 0.6654334315503624, 'gt.brier_score': 0.15120604857477493, 'syn_id.c_index': 0.6330676237824038, 'syn_id.brier_score': 0.17433459614622904, 'syn_ood.c_index': 0.6347711754571775, 'syn_ood.brier_score': 0.17898369974451991}
# maggic xgb survival_gan 1 {'gt.c_index': 0.6654334315503624, 'gt.brier_score': 0.15120604857477493, 'syn_id.c_index': 0.575788000307857, 'syn_id.brier_score': 0.18412801136219992, 'syn_ood.c_index': 0.5774669041777848, 'syn_ood.brier_score': 0.19151403324599658}
# maggic xgb survival_gan 2 {'gt.c_index': 0.6654334315503624, 'gt.brier_score': 0.15120604857477493, 'syn_id.c_index': 0.6262730181469522, 'syn_id.brier_score': 0.1742823519423781, 'syn_ood.c_index': 0.6252707348144699, 'syn_ood.brier_score': 0.180402368625159}
# maggic xgb ctgan 0 {'gt.c_index': 0.6654334315503624, 'gt.brier_score': 0.15120604857477493, 'syn_id.c_index': 0.5879598233338613, 'syn_id.brier_score': 0.1921943952931453, 'syn_ood.c_index': 0.5828279669020512, 'syn_ood.brier_score': 0.1994609822930423}
# maggic xgb ctgan 1 {'gt.c_index': 0.6654334315503624, 'gt.brier_score': 0.15120604857477493, 'syn_id.c_index': 0.6113298571991118, 'syn_id.brier_score': 0.17768794482210729, 'syn_ood.c_index': 0.6064588205023541, 'syn_ood.brier_score': 0.184975819498722}
# maggic xgb ctgan 2 {'gt.c_index': 0.6654334315503624, 'gt.brier_score': 0.15120604857477493, 'syn_id.c_index': 0.6168577914317082, 'syn_id.brier_score': 0.17714476100787024, 'syn_ood.c_index': 0.6137101246463434, 'syn_ood.brier_score': 0.18264759072299616}
# maggic xgb nflow 0 {'gt.c_index': 0.6654334315503624, 'gt.brier_score': 0.15120604857477493, 'syn_id.c_index': 0.5628085438774532, 'syn_id.brier_score': 0.19425529369929026, 'syn_ood.c_index': 0.562636851349216, 'syn_ood.brier_score': 0.1954347983895562}
# maggic xgb nflow 1 {'gt.c_index': 0.6654334315503624, 'gt.brier_score': 0.15120604857477493, 'syn_id.c_index': 0.5493922978071701, 'syn_id.brier_score': 0.20508313734874992, 'syn_ood.c_index': 0.5492959840364038, 'syn_ood.brier_score': 0.20770980457147925}
# maggic xgb nflow 2 {'gt.c_index': 0.6654334315503624, 'gt.brier_score': 0.15120604857477493, 'syn_id.c_index': 0.5603489081797673, 'syn_id.brier_score': 0.17175082215027296, 'syn_ood.c_index': 0.568437746527732, 'syn_ood.brier_score': 0.1728822538128839}
# maggic xgb tvae 0 {'gt.c_index': 0.6654334315503624, 'gt.brier_score': 0.15120604857477493, 'syn_id.c_index': 0.5988797766124134, 'syn_id.brier_score': 0.19537075267154946, 'syn_ood.c_index': 0.594482553410501, 'syn_ood.brier_score': 0.20604006071015424}
# maggic xgb tvae 1 {'gt.c_index': 0.6654334315503624, 'gt.brier_score': 0.15120604857477493, 'syn_id.c_index': 0.6291039296807772, 'syn_id.brier_score': 0.1906121852537277, 'syn_ood.c_index': 0.6291677646517456, 'syn_ood.brier_score': 0.1975788509127702}
# maggic xgb tvae 2 {'gt.c_index': 0.6654334315503624, 'gt.brier_score': 0.15120604857477493, 'syn_id.c_index': 0.6379702220039148, 'syn_id.brier_score': 0.21190243203761935, 'syn_ood.c_index': 0.6421990908810774, 'syn_ood.brier_score': 0.22105759327378308}
# maggic xgb privbayes 0 {'gt.c_index': 0.6654334315503624, 'gt.brier_score': 0.15120604857477493, 'syn_id.c_index': 0.5559236559248188, 'syn_id.brier_score': 0.21225320168858539, 'syn_ood.c_index': 0.5535910604530823, 'syn_ood.brier_score': 0.21348680180120702}
# maggic xgb privbayes 1 {'gt.c_index': 0.6654334315503624, 'gt.brier_score': 0.15120604857477493, 'syn_id.c_index': 0.5706480211951271, 'syn_id.brier_score': 0.2004335079078238, 'syn_ood.c_index': 0.5702533702912341, 'syn_ood.brier_score': 0.2018138326918879}
# maggic xgb privbayes 2 {'gt.c_index': 0.6654334315503624, 'gt.brier_score': 0.15120604857477493, 'syn_id.c_index': 0.5480649920117882, 'syn_id.brier_score': 0.2054443173255658, 'syn_ood.c_index': 0.5463853767055479, 'syn_ood.brier_score': 0.206219772478658}
# maggic xgb adsgan 0 {'gt.c_index': 0.6654334315503624, 'gt.brier_score': 0.15120604857477493, 'syn_id.c_index': 0.5793840253114544, 'syn_id.brier_score': 0.35721510080532465, 'syn_ood.c_index': 0.5792621553530561, 'syn_ood.brier_score': 0.35801207436553883}
# maggic xgb adsgan 1 {'gt.c_index': 0.6654334315503624, 'gt.brier_score': 0.15120604857477493, 'syn_id.c_index': 0.5805672843068237, 'syn_id.brier_score': 0.18790408397469363, 'syn_ood.c_index': 0.5806771273260792, 'syn_ood.brier_score': 0.19855326672934534}
# maggic xgb adsgan 2 {'gt.c_index': 0.6654334315503624, 'gt.brier_score': 0.15120604857477493, 'syn_id.c_index': 0.516153366184642, 'syn_id.brier_score': 0.21521658678227126, 'syn_ood.c_index': 0.5139560152795964, 'syn_ood.brier_score': 0.20912624217418072}
# maggic linear_model survival_gan 0 {'gt.c_index': 0.6632499286175375, 'gt.brier_score': 0.14648157483114163, 'syn_id.c_index': 0.6503047777247094, 'syn_id.brier_score': 0.4388141599129227, 'syn_ood.c_index': 0.6506400145488697, 'syn_ood.brier_score': 0.45038374747411036}
# maggic linear_model survival_gan 1 {'gt.c_index': 0.6632499286175375, 'gt.brier_score': 0.14648157483114163, 'syn_id.c_index': 0.6343259968134374, 'syn_id.brier_score': 0.17518064476408438, 'syn_ood.c_index': 0.6331425725797539, 'syn_ood.brier_score': 0.17775060811270915}
# maggic linear_model survival_gan 2 {'gt.c_index': 0.6632499286175375, 'gt.brier_score': 0.14648157483114163, 'syn_id.c_index': 0.6401337262182103, 'syn_id.brier_score': 0.18540599065636343, 'syn_ood.c_index': 0.642070835841678, 'syn_ood.brier_score': 0.1831008961403139}
# maggic linear_model ctgan 0 {'gt.c_index': 0.6632499286175375, 'gt.brier_score': 0.14648157483114163, 'syn_id.c_index': 0.6179363117925294, 'syn_id.brier_score': 0.43612850326677005, 'syn_ood.c_index': 0.6148440120262184, 'syn_ood.brier_score': 0.44618053533735985}
# maggic linear_model ctgan 1 {'gt.c_index': 0.6632499286175375, 'gt.brier_score': 0.14648157483114163, 'syn_id.c_index': 0.6153734044305944, 'syn_id.brier_score': 0.42993278412303254, 'syn_ood.c_index': 0.6134155706654828, 'syn_ood.brier_score': 0.440438276154363}
# maggic linear_model ctgan 2 {'gt.c_index': 0.6632499286175375, 'gt.brier_score': 0.14648157483114163, 'syn_id.c_index': 0.5865876253051737, 'syn_id.brier_score': 0.42374040365278204, 'syn_ood.c_index': 0.5821084466200495, 'syn_ood.brier_score': 0.434120819361777}
# maggic linear_model nflow 0 {'gt.c_index': 0.6632499286175375, 'gt.brier_score': 0.14648157483114163, 'syn_id.c_index': 0.5820328344147142, 'syn_id.brier_score': 0.19240624231951686, 'syn_ood.c_index': 0.5780066460409303, 'syn_ood.brier_score': 0.19308680792690755}
# maggic linear_model nflow 1 {'gt.c_index': 0.6632499286175375, 'gt.brier_score': 0.14648157483114163, 'syn_id.c_index': 0.5652627988084533, 'syn_id.brier_score': 0.21142952205995016, 'syn_ood.c_index': 0.565385916370452, 'syn_ood.brier_score': 0.21315559006124238}
# maggic linear_model nflow 2 {'gt.c_index': 0.6632499286175375, 'gt.brier_score': 0.14648157483114163, 'syn_id.c_index': 0.5463303430990597, 'syn_id.brier_score': 0.19959253114334952, 'syn_ood.c_index': 0.5471859843696462, 'syn_ood.brier_score': 0.19891711725674557}
# maggic linear_model tvae 0 {'gt.c_index': 0.6632499286175375, 'gt.brier_score': 0.14648157483114163, 'syn_id.c_index': 0.5490558879666398, 'syn_id.brier_score': 0.5075412197046312, 'syn_ood.c_index': 0.5492515057616242, 'syn_ood.brier_score': 0.5195589466359359}
# maggic linear_model tvae 1 {'gt.c_index': 0.6632499286175375, 'gt.brier_score': 0.14648157483114163, 'syn_id.c_index': 0.6256492980735915, 'syn_id.brier_score': 0.44962845474543495, 'syn_ood.c_index': 0.6270972107114413, 'syn_ood.brier_score': 0.46210329204622763}
# maggic linear_model tvae 2 {'gt.c_index': 0.6632499286175375, 'gt.brier_score': 0.14648157483114163, 'syn_id.c_index': 0.5917229754306151, 'syn_id.brier_score': 0.45731844512160696, 'syn_ood.c_index': 0.5911000418925705, 'syn_ood.brier_score': 0.4717002768271124}
# maggic linear_model privbayes 0 {'gt.c_index': 0.6632499286175375, 'gt.brier_score': 0.14648157483114163, 'syn_id.c_index': 0.5662601840400737, 'syn_id.brier_score': 0.2131363301545296, 'syn_ood.c_index': 0.5669192792327395, 'syn_ood.brier_score': 0.213672207236382}
# maggic linear_model privbayes 1 {'gt.c_index': 0.6632499286175375, 'gt.brier_score': 0.14648157483114163, 'syn_id.c_index': 0.5738493862754872, 'syn_id.brier_score': 0.20366988943286582, 'syn_ood.c_index': 0.5765792991544975, 'syn_ood.brier_score': 0.20425301654785236}
# maggic linear_model privbayes 2 {'gt.c_index': 0.6632499286175375, 'gt.brier_score': 0.14648157483114163, 'syn_id.c_index': 0.5799798650315148, 'syn_id.brier_score': 0.2045625893561962, 'syn_ood.c_index': 0.5810228644189331, 'syn_ood.brier_score': 0.2059217558411031}
# maggic linear_model adsgan 0 {'gt.c_index': 0.6632499286175375, 'gt.brier_score': 0.14648157483114163, 'syn_id.c_index': 0.5330738396625954, 'syn_id.brier_score': 0.6833223555525958, 'syn_ood.c_index': 0.5361804823186805, 'syn_ood.brier_score': 0.6876754348272368}
# maggic linear_model adsgan 1 {'gt.c_index': 0.6632499286175375, 'gt.brier_score': 0.14648157483114163, 'syn_id.c_index': 0.5656332292499284, 'syn_id.brier_score': 0.46727502467487175, 'syn_ood.c_index': 0.5659152787427425, 'syn_ood.brier_score': 0.48223452209200107}
# maggic linear_model adsgan 2 {'gt.c_index': 0.6632499286175375, 'gt.brier_score': 0.14648157483114163, 'syn_id.c_index': 0.48675875691389353, 'syn_id.brier_score': 0.5416346881961017, 'syn_ood.c_index': 0.48261815678795017, 'syn_ood.brier_score': 0.5429256761898683}
# =======================
# Evaluate  seer
# seer mlp survival_gan 0 {'gt.c_index': 0.5000004041745689, 'gt.brier_score': 0.02412814886111232, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.026039657151882833, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.025576156578280145}
# seer mlp survival_gan 1 {'gt.c_index': 0.5000004041745689, 'gt.brier_score': 0.02412814886111232, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.024177845268765107, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.02413232719705384}
# seer mlp survival_gan 2 {'gt.c_index': 0.5000004041745689, 'gt.brier_score': 0.02412814886111232, 'syn_id.c_index': 0.5000252864096146, 'syn_id.brier_score': 0.039814137272375864, 'syn_ood.c_index': 0.5001266850867621, 'syn_ood.brier_score': 0.03877040837008744}
# seer mlp ctgan 0 {'gt.c_index': 0.5000004041745689, 'gt.brier_score': 0.02412814886111232, 'syn_id.c_index': 0.8116450109088582, 'syn_id.brier_score': 0.08061988389914133, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.15493806825413384}
# seer mlp ctgan 1 {'gt.c_index': 0.5000004041745689, 'gt.brier_score': 0.02412814886111232, 'syn_id.c_index': 0.7020943699734419, 'syn_id.brier_score': 0.21394730517597393, 'syn_ood.c_index': 0.7212235243483769, 'syn_ood.brier_score': 0.2412876251711149}
# seer mlp ctgan 2 {'gt.c_index': 0.5000004041745689, 'gt.brier_score': 0.02412814886111232, 'syn_id.c_index': 0.6549192619871326, 'syn_id.brier_score': 0.19823010768829505, 'syn_ood.c_index': 0.7742860676152183, 'syn_ood.brier_score': 0.1847031397988701}
# seer mlp nflow 0 {'gt.c_index': 0.5000004041745689, 'gt.brier_score': 0.02412814886111232, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.318466587628651, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.3175816236816999}
# seer mlp nflow 1 {'gt.c_index': 0.5000004041745689, 'gt.brier_score': 0.02412814886111232, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.17878510971345607, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.17831593041104574}
# seer mlp nflow 2 {'gt.c_index': 0.5000004041745689, 'gt.brier_score': 0.02412814886111232, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.11299145124623644, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.1139921561537323}
# seer mlp tvae 0 {'gt.c_index': 0.5000004041745689, 'gt.brier_score': 0.02412814886111232, 'syn_id.c_index': 0.5273689736293549, 'syn_id.brier_score': 0.024827854154770734, 'syn_ood.c_index': 0.5391989675216394, 'syn_ood.brier_score': 0.024857947658304624}
# seer mlp tvae 1 {'gt.c_index': 0.5000004041745689, 'gt.brier_score': 0.02412814886111232, 'syn_id.c_index': 0.5207843819096908, 'syn_id.brier_score': 0.024863105983329636, 'syn_ood.c_index': 0.5311094603699845, 'syn_ood.brier_score': 0.024851865199464734}
# seer mlp tvae 2 {'gt.c_index': 0.5000004041745689, 'gt.brier_score': 0.02412814886111232, 'syn_id.c_index': 0.5310073352235317, 'syn_id.brier_score': 0.024869695332065834, 'syn_ood.c_index': 0.5320247579423274, 'syn_ood.brier_score': 0.024811511332274102}
# seer mlp privbayes 0 {'gt.c_index': 0.5000004041745689, 'gt.brier_score': 0.02412814886111232, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.02414315240763884, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.024142282606263322}
# seer mlp privbayes 1 {'gt.c_index': 0.5000004041745689, 'gt.brier_score': 0.02412814886111232, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.024135047343919986, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.024133100040983953}
# seer mlp privbayes 2 {'gt.c_index': 0.5000004041745689, 'gt.brier_score': 0.02412814886111232, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.024136339519988035, 'syn_ood.c_index': 0.5, 'syn_ood.brier_score': 0.024156118166323667}
# seer mlp adsgan 0 {'gt.c_index': 0.5000004041745689, 'gt.brier_score': 0.02412814886111232, 'syn_id.c_index': 0.0, 'syn_id.brier_score': 1.0, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# seer mlp adsgan 1 {'gt.c_index': 0.5000004041745689, 'gt.brier_score': 0.02412814886111232, 'syn_id.c_index': 0.0, 'syn_id.brier_score': 1.0, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# seer mlp adsgan 2 {'gt.c_index': 0.5000004041745689, 'gt.brier_score': 0.02412814886111232, 'syn_id.c_index': 0.0, 'syn_id.brier_score': 1.0, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# seer xgb survival_gan 0 {'gt.c_index': 0.8521464322079112, 'gt.brier_score': 0.021661690647627116, 'syn_id.c_index': 0.8245491986858733, 'syn_id.brier_score': 0.021973354048700617, 'syn_ood.c_index': 0.8300345303723828, 'syn_ood.brier_score': 0.021844831261625754}
# seer xgb survival_gan 1 {'gt.c_index': 0.8521464322079112, 'gt.brier_score': 0.021661690647627116, 'syn_id.c_index': 0.8224430717561252, 'syn_id.brier_score': 0.022558551284684647, 'syn_ood.c_index': 0.8320651460589995, 'syn_ood.brier_score': 0.022478355436141472}
# seer xgb survival_gan 2 {'gt.c_index': 0.8521464322079112, 'gt.brier_score': 0.021661690647627116, 'syn_id.c_index': 0.6933311105987897, 'syn_id.brier_score': 0.02393041504267891, 'syn_ood.c_index': 0.6941620434764183, 'syn_ood.brier_score': 0.02400423089554961}
# seer xgb ctgan 0 {'gt.c_index': 0.8521464322079112, 'gt.brier_score': 0.021661690647627116, 'syn_id.c_index': 0.8187327037939363, 'syn_id.brier_score': 0.08478474151183461, 'syn_ood.c_index': 0.8109349198135041, 'syn_ood.brier_score': 0.0840426414404048}
# seer xgb ctgan 1 {'gt.c_index': 0.8521464322079112, 'gt.brier_score': 0.021661690647627116, 'syn_id.c_index': 0.810968745865453, 'syn_id.brier_score': 0.167725107660178, 'syn_ood.c_index': 0.8089782055852961, 'syn_ood.brier_score': 0.16606136715538097}
# seer xgb ctgan 2 {'gt.c_index': 0.8521464322079112, 'gt.brier_score': 0.021661690647627116, 'syn_id.c_index': 0.7669998354004542, 'syn_id.brier_score': 0.15507710340541211, 'syn_ood.c_index': 0.773468076143976, 'syn_ood.brier_score': 0.15353432936427258}
# seer xgb nflow 0 {'gt.c_index': 0.8521464322079112, 'gt.brier_score': 0.021661690647627116, 'syn_id.c_index': 0.6126398235444455, 'syn_id.brier_score': 0.2506106121490756, 'syn_ood.c_index': 0.5875724979038363, 'syn_ood.brier_score': 0.25119403036887683}
# seer xgb nflow 1 {'gt.c_index': 0.8521464322079112, 'gt.brier_score': 0.021661690647627116, 'syn_id.c_index': 0.595892456863543, 'syn_id.brier_score': 0.15911767124792978, 'syn_ood.c_index': 0.5940389090755374, 'syn_ood.brier_score': 0.15878259787838614}
# seer xgb nflow 2 {'gt.c_index': 0.8521464322079112, 'gt.brier_score': 0.021661690647627116, 'syn_id.c_index': 0.6906841458558701, 'syn_id.brier_score': 0.07555237738137502, 'syn_ood.c_index': 0.6889375355120769, 'syn_ood.brier_score': 0.07560516089413029}
# seer xgb tvae 0 {'gt.c_index': 0.8521464322079112, 'gt.brier_score': 0.021661690647627116, 'syn_id.c_index': 0.8302920867625797, 'syn_id.brier_score': 0.024034250039770225, 'syn_ood.c_index': 0.8359323272073681, 'syn_ood.brier_score': 0.023998900075255004}
# ...
# seer linear_model tvae 0 {'gt.c_index': 0.8478194755263354, 'gt.brier_score': 0.020776657214431535, 'syn_id.c_index': 0.7375580154214258, 'syn_id.brier_score': 0.023915225516359852, 'syn_ood.c_index': 0.7502292432639358, 'syn_ood.brier_score': 0.023878950787843255}
# seer linear_model tvae 1 {'gt.c_index': 0.8478194755263354, 'gt.brier_score': 0.020776657214431535, 'syn_id.c_index': 0.6414456714904762, 'syn_id.brier_score': 0.02430013122751774, 'syn_ood.c_index': 0.6487184389598107, 'syn_ood.brier_score': 0.02428149058222241}
# seer linear_model tvae 2 {'gt.c_index': 0.8478194755263354, 'gt.brier_score': 0.020776657214431535, 'syn_id.c_index': 0.7504784826191481, 'syn_id.brier_score': 0.023811522877745166, 'syn_ood.c_index': 0.7691756705464318, 'syn_ood.brier_score': 0.02380662817985475}
# seer linear_model privbayes 0 {'gt.c_index': 0.8478194755263354, 'gt.brier_score': 0.020776657214431535, 'syn_id.c_index': 0.276242374407974, 'syn_id.brier_score': 0.02416126501528054, 'syn_ood.c_index': 0.2604718500733248, 'syn_ood.brier_score': 0.024160349335648035}
# seer linear_model privbayes 1 {'gt.c_index': 0.8478194755263354, 'gt.brier_score': 0.020776657214431535, 'syn_id.c_index': 0.7410334116315648, 'syn_id.brier_score': 0.02407166186520604, 'syn_ood.c_index': 0.7388288322401664, 'syn_ood.brier_score': 0.0240703519782143}
# seer linear_model privbayes 2 {'gt.c_index': 0.8478194755263354, 'gt.brier_score': 0.020776657214431535, 'syn_id.c_index': 0.5160766836602305, 'syn_id.brier_score': 0.024120435360052792, 'syn_ood.c_index': 0.4928148139874826, 'syn_ood.brier_score': 0.024122150942609413}
# seer linear_model adsgan 0 {'gt.c_index': 0.8478194755263354, 'gt.brier_score': 0.020776657214431535, 'syn_id.c_index': 0.0, 'syn_id.brier_score': 1.0, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# seer linear_model adsgan 1 {'gt.c_index': 0.8478194755263354, 'gt.brier_score': 0.020776657214431535, 'syn_id.c_index': 0.0, 'syn_id.brier_score': 1.0, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# seer linear_model adsgan 2 {'gt.c_index': 0.8478194755263354, 'gt.brier_score': 0.020776657214431535, 'syn_id.c_index': 0.0, 'syn_id.brier_score': 1.0, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# {'aids': {'mlp': {'gt': {'c_index': 0.7059304149697022,
#     'brier_score': 0.06806232093352434},
#    'survival_gan': {'c_index': [0.6454852592877075,
#      0.7165071752721839,
#      0.7644641382612013],
#     'brier_score': [0.07742694851561303,
#      0.07776424405215514,
#      0.07990441130531196]},
#    'ctgan': {'c_index': [0.0, 0.520568649905171, 0.5542162720615037],
#     'brier_score': [1.0, 0.07613622330571594, 0.10876656241751877]},
#    'nflow': {'c_index': [0.3836290426816391,
#      0.37855223712306135,
#      0.5309118212646274],
#     'brier_score': [0.1360939367406394,
#      0.16071780684920026,
#      0.1273532349081433]},
#    'tvae': {'c_index': [0.0, 0.4973162193929452, 0.0],
#     'brier_score': [1.0, 0.07745913854287934, 1.0]},
#    'privbayes': {'c_index': [0.47586271354782933,
#      0.4173548020659998,
#      0.2991700915100185],
#     'brier_score': [0.07847409831109108,
#      0.09323820812133977,
#      0.07883306714479758]},
#    'adsgan': {'c_index': [0.0, 0.5985419306860772, 0.0],
#     'brier_score': [1.0, 0.07675083822459335, 1.0]}},
#   'xgb': {'gt': {'c_index': 0.7356953628118555,
#     'brier_score': 0.062788404425297},
#    'survival_gan': {'c_index': [0.5742303039522929,
#      0.7854100648404208,
#      0.7085975400715928],
#     'brier_score': [0.07134156171436111,
#      0.06900873680903102,
#      0.06915268699578814]},
#    'ctgan': {'c_index': [0.6822746913277724,
#      0.4987423458317919,
#      0.7374737093767485],
#     'brier_score': [0.0721676595982021,
#      0.07289199673517642,
#      0.07400613390613633]},
#    'nflow': {'c_index': [0.46994320089725,
#      0.594376683161613,
#      0.44862952170621034],
#     'brier_score': [0.09653666803379451,
#      0.14253265702892295,
#      0.09818776283163667]},
#    'tvae': {'c_index': [0.5, 0.6885742237330555, 0.5],
#     'brier_score': [0.07746034739915574,
#      0.0773043198558032,
#      0.0773128618326687]},
#    'privbayes': {'c_index': [0.5888151534188154,
#      0.4782561856210427,
#      0.5732327893991209],
#     'brier_score': [0.0752125027563393,
#      0.07169927381484396,
#      0.07228436595620757]},
#    'adsgan': {'c_index': [0.5, 0.6940310329823038, 0.5],
#     'brier_score': [0.07746034739915574,
#      0.0727556481660794,
#      0.07746034739915574]}},
#   'linear_model': {'gt': {'c_index': 0.7376085764258152,
#     'brier_score': 0.061707863206065416},
#    'survival_gan': {'c_index': [0.0, 0.0, 0.0],
#     'brier_score': [1.0, 1.0, 1.0]},
#    'ctgan': {'c_index': [0.6949089269268556,
#      0.45723162100221026,
#      0.7866488639578796],
#     'brier_score': [0.0711931786732762,
#      0.07391699898006086,
#      0.06988575971496876]},
#    'nflow': {'c_index': [0.5648951840565446,
#      0.48358208181378104,
#      0.46960948352234677],
#     'brier_score': [0.0913250877813039,
#      0.12747251100036605,
#      0.11552923188934193]},
#    'tvae': {'c_index': [0.0, 0.5136704390235118, 0.49570821101240287],
#     'brier_score': [1.0, 0.09986260268150948, 0.10206638969837839]},
#    'privbayes': {'c_index': [0.5756952632093969,
#      0.5276712033890112,
#      0.5092327753601479],
#     'brier_score': [0.0744624317655898,
#      0.07174982366218323,
#      0.07360596121188029]},
#    'adsgan': {'c_index': [0.0, 0.5181922792673933, 0.0],
#     'brier_score': [1.0, 0.174300646655429, 1.0]}}},
#  'cutract': {'mlp': {'gt': {'c_index': 0.7227856874466392,
#     'brier_score': 0.09078878664723468},
#    'survival_gan': {'c_index': [0.6773662560026695,
#      0.7745746052534509,
#      0.7781613895561756],
#     'brier_score': [0.09294071269302889,
#      0.08433732524161704,
#      0.10017100712450633]},
#    'ctgan': {'c_index': [0.7553184846865162,
#      0.6777539893172868,
#      0.7390306737034017],
#     'brier_score': [0.1849173173231573,
#      0.23579553681046647,
#      0.18296172823834211]},
#    'nflow': {'c_index': [0.5, 0.5, 0.5],
#     'brier_score': [0.2118141694051856,
#      0.21303283198093467,
#      0.21931965645569998]},
#    'tvae': {'c_index': [0.6672435193952179,
#      0.6501148589004849,
#      0.6103256770969473],
#     'brier_score': [0.13643659037389988,
#      0.1334711128785412,
#      0.16894916327383427]},
#    'privbayes': {'c_index': [0.5011914114529299, 0.5, 0.4985786034674285],
#     'brier_score': [0.09919928763334858,
#      0.09969794997165378,
#      0.0995445068894776]},
#    'adsgan': {'c_index': [0.6219788013585114, 0.0, 0.5566569436601775],
#     'brier_score': [0.11203897652360846, 1.0, 0.10351229775096223]}},
#   'xgb': {'gt': {'c_index': 0.8319374581013449,
#     'brier_score': 0.08457689286909124},
#    'survival_gan': {'c_index': [0.7741866546777638,
#      0.7804397937915969,
#      0.7746854689867586],
#     'brier_score': [0.08556463616200416,
#      0.08799037954154254,
#      0.0857674646153521]},
#    'ctgan': {'c_index': [0.7695774796569266,
#      0.775619153193384,
#      0.7781166464936881],
#     'brier_score': [0.19355249482568615,
#      0.2291775444741634,
#      0.2019013182753212]},
#    'nflow': {'c_index': [0.6836882506780282,
#      0.5049244070795614,
#      0.5166486927515807],
#     'brier_score': [0.19911975079772234,
#      0.2131364511566044,
#      0.21327164845258859]},
#    'tvae': {'c_index': [0.7186431662866388,
#      0.7422151554796939,
#      0.7627922954211982],
#     'brier_score': [0.09965156765209891,
#      0.09820782415698236,
#      0.09525052497309039]},
#    'privbayes': {'c_index': [0.4845736296490728,
#      0.4075450577243777,
#      0.586645728190701],
#     'brier_score': [0.09933357859454749,
#      0.10075102540197052,
#      0.09879764689271786]},
#    'adsgan': {'c_index': [0.711142646483426, 0.5, 0.587557517681081],
#     'brier_score': [0.11389588655609607,
#      0.11468457957758581,
#      0.11116755994790765]}},
#   'linear_model': {'gt': {'c_index': 0.8098309079742018,
#     'brier_score': 0.07536036182071539},
#    'survival_gan': {'c_index': [0.7626953767923544,
#      0.7568697049687904,
#      0.7687297248123496],
#     'brier_score': [0.08435359446666808,
#      0.0870116494443915,
#      0.10819228259054055]},
#    'ctgan': {'c_index': [0.7586253153808049,
#      0.7676091861839117,
#      0.7680070547371444],
#     'brier_score': [0.1686652101277557,
#      0.21098839351746976,
#      0.17083589343851488]},
#    'nflow': {'c_index': [0.7246664538005613,
#      0.5830555439090589,
#      0.6586605983597654],
#     'brier_score': [0.19298591661162987,
#      0.19398797773963763,
#      0.21662508718053938]},
#    'tvae': {'c_index': [0.7647022446718711,
#      0.7500175950992182,
#      0.7730655791592701],
#     'brier_score': [0.10632582258976275,
#      0.10316631787731234,
#      0.09992020036853022]},
#    'privbayes': {'c_index': [0.48398111402388005,
#      0.33731524870343793,
#      0.46263432096907015],
#     'brier_score': [0.0994239958937826,
#      0.10190681977567288,
#      0.0996153281745405]},
#    'adsgan': {'c_index': [0.7233637838538503, 0.0, 0.3924229936801327],
#     'brier_score': [0.11152711481069337, 1.0, 0.11896602051966236]}}},
#  'maggic': {'mlp': {'gt': {'c_index': 0.6351989261191153,
#     'brier_score': 0.1679785580062451},
#    'survival_gan': {'c_index': [0.5451663572193332,
#      0.6132180676114923,
#      0.6407541317291121],
#     'brier_score': [0.1847187674345568,
#      0.1838610067650488,
#      0.17898222405093908]},
#    'ctgan': {'c_index': [0.4997565094398053,
#      0.5004247032471466,
#      0.49892071942860367],
#     'brier_score': [0.20289603605986942,
#      0.19245772797563043,
#      0.19649597639613162]},
#    'nflow': {'c_index': [0.5, 0.5, 0.5],
#     'brier_score': [0.19279772197451106,
#      0.1905426105930417,
#      0.1940005379882294]},
#    'tvae': {'c_index': [0.5413940319523554,
#      0.5536179448335039,
#      0.5356216133258178],
#     'brier_score': [0.2210225085691858,
#      0.21255836419563423,
#      0.21067922115545704]},
#    'privbayes': {'c_index': [0.5, 0.5, 0.5],
#     'brier_score': [0.21609710425173811,
#      0.20754231534156667,
#      0.20696313974108368]},
#    'adsgan': {'c_index': [0.5049834223015863,
#      0.5334826640220739,
#      0.5105364847317403],
#     'brier_score': [0.22621436388118185,
#      0.23016003082697867,
#      0.24244769043557493]}},
#   'xgb': {'gt': {'c_index': 0.6654334315503624,
#     'brier_score': 0.15120604857477493},
#    'survival_gan': {'c_index': [0.6347711754571775,
#      0.5774669041777848,
#      0.6252707348144699],
#     'brier_score': [0.17898369974451991,
#      0.19151403324599658,
#      0.180402368625159]},
#    'ctgan': {'c_index': [0.5828279669020512,
#      0.6064588205023541,
#      0.6137101246463434],
#     'brier_score': [0.1994609822930423,
#      0.184975819498722,
#      0.18264759072299616]},
#    'nflow': {'c_index': [0.562636851349216,
#      0.5492959840364038,
#      0.568437746527732],
#     'brier_score': [0.1954347983895562,
#      0.20770980457147925,
#      0.1728822538128839]},
#    'tvae': {'c_index': [0.594482553410501,
#      0.6291677646517456,
#      0.6421990908810774],
#     'brier_score': [0.20604006071015424,
#      0.1975788509127702,
#      0.22105759327378308]},
#    'privbayes': {'c_index': [0.5535910604530823,
#      0.5702533702912341,
#      0.5463853767055479],
#     'brier_score': [0.21348680180120702,
#      0.2018138326918879,
#      0.206219772478658]},
#    'adsgan': {'c_index': [0.5792621553530561,
#      0.5806771273260792,
#      0.5139560152795964],
#     'brier_score': [0.35801207436553883,
#      0.19855326672934534,
#      0.20912624217418072]}},
#   'linear_model': {'gt': {'c_index': 0.6632499286175375,
#     'brier_score': 0.14648157483114163},
#    'survival_gan': {'c_index': [0.6506400145488697,
#      0.6331425725797539,
#      0.642070835841678],
#     'brier_score': [0.45038374747411036,
#      0.17775060811270915,
#      0.1831008961403139]},
#    'ctgan': {'c_index': [0.6148440120262184,
#      0.6134155706654828,
#      0.5821084466200495],
#     'brier_score': [0.44618053533735985,
#      0.440438276154363,
#      0.434120819361777]},
#    'nflow': {'c_index': [0.5780066460409303,
#      0.565385916370452,
#      0.5471859843696462],
#     'brier_score': [0.19308680792690755,
#      0.21315559006124238,
#      0.19891711725674557]},
#    'tvae': {'c_index': [0.5492515057616242,
#      0.6270972107114413,
#      0.5911000418925705],
#     'brier_score': [0.5195589466359359,
#      0.46210329204622763,
#      0.4717002768271124]},
#    'privbayes': {'c_index': [0.5669192792327395,
#      0.5765792991544975,
#      0.5810228644189331],
#     'brier_score': [0.213672207236382,
#      0.20425301654785236,
#      0.2059217558411031]},
#    'adsgan': {'c_index': [0.5361804823186805,
#      0.5659152787427425,
#      0.48261815678795017],
#     'brier_score': [0.6876754348272368,
#      0.48223452209200107,
#      0.5429256761898683]}}},
#  'seer': {'mlp': {'gt': {'c_index': 0.5000004041745689,
#     'brier_score': 0.02412814886111232},
#    'survival_gan': {'c_index': [0.5, 0.5, 0.5001266850867621],
#     'brier_score': [0.025576156578280145,
#      0.02413232719705384,
#      0.03877040837008744]},
#    'ctgan': {'c_index': [0.5, 0.7212235243483769, 0.7742860676152183],
#     'brier_score': [0.15493806825413384,
#      0.2412876251711149,
#      0.1847031397988701]},
#    'nflow': {'c_index': [0.5, 0.5, 0.5],
#     'brier_score': [0.3175816236816999,
#      0.17831593041104574,
#      0.1139921561537323]},
#    'tvae': {'c_index': [0.5391989675216394,
#      0.5311094603699845,
#      0.5320247579423274],
#     'brier_score': [0.024857947658304624,
#      0.024851865199464734,
#      0.024811511332274102]},
#    'privbayes': {'c_index': [0.5, 0.5, 0.5],
#     'brier_score': [0.024142282606263322,
#      0.024133100040983953,
#      0.024156118166323667]},
#    'adsgan': {'c_index': [0.0, 0.0, 0.0], 'brier_score': [1.0, 1.0, 1.0]}},
#   'xgb': {'gt': {'c_index': 0.8521464322079112,
#     'brier_score': 0.021661690647627116},
#    'survival_gan': {'c_index': [0.8300345303723828,
#      0.8320651460589995,
#      0.6941620434764183],
#     'brier_score': [0.021844831261625754,
#      0.022478355436141472,
#      0.02400423089554961]},
#    'ctgan': {'c_index': [0.8109349198135041,
#      0.8089782055852961,
#      0.773468076143976],
#     'brier_score': [0.0840426414404048,
#      0.16606136715538097,
#      0.15353432936427258]},
#    'nflow': {'c_index': [0.5875724979038363,
#      0.5940389090755374,
#      0.6889375355120769],
#     'brier_score': [0.25119403036887683,
#      0.15878259787838614,
#      0.07560516089413029]},
#    'tvae': {'c_index': [0.8359323272073681,
#      0.7806821933822493,
#      0.8122737228861222],
#     'brier_score': [0.023998900075255004,
#      0.02482901813637536,
#      0.024503811779296558]},
#    'privbayes': {'c_index': [0.3889121899194545,
#      0.5248054074908431,
#      0.3928798820789276],
#     'brier_score': [0.024151075100059465,
#      0.02414781016591738,
#      0.02416185866335067]},
#    'adsgan': {'c_index': [0.5, 0.5, 0.5],
#     'brier_score': [0.024896275616259202,
#      0.024896275616259202,
#      0.024896275616259202]}},
#   'linear_model': {'gt': {'c_index': 0.8478194755263354,
#     'brier_score': 0.020776657214431535},
#    'survival_gan': {'c_index': [0.8462229709304018,
#      0.8286079327437789,
#      0.8231901100413107],
#     'brier_score': [0.021506527394729944,
#      0.02144260306350441,
#      0.02856377118884193]},
#    'ctgan': {'c_index': [0.839219164165527,
#      0.85242590701232,
#      0.8229119745696541],
#     'brier_score': [0.07670902991276568,
#      0.17020673154068353,
#      0.15579968249278145]},
#    'nflow': {'c_index': [0.8054196286303469,
#      0.8149448709121758,
#      0.7313478770791227],
#     'brier_score': [0.3029290575348027,
#      0.15834672995370244,
#      0.09040636952763342]},
#    'tvae': {'c_index': [0.7502292432639358,
#      0.6487184389598107,
#      0.7691756705464318],
#     'brier_score': [0.023878950787843255,
#      0.02428149058222241,
#      0.02380662817985475]},
#    'privbayes': {'c_index': [0.2604718500733248,
#      0.7388288322401664,
#      0.4928148139874826],
#     'brier_score': [0.024160349335648035,
#      0.0240703519782143,
#      0.024122150942609413]},
#    'adsgan': {'c_index': [0.0, 0.0, 0.0], 'brier_score': [1.0, 1.0, 1.0]}}}}

# %%
## metabric

from pathlib import Path

import tabulate
from adjutorium.plugins.prediction.risk_estimation import RiskEstimation
from adjutorium.utils.metrics import generate_score, print_score
from synthcity.metrics.eval_statistical import JensenShannonDistance
from synthcity.plugins.core.dataloader import SurvivalAnalysisDataLoader
from synthcity.utils.serialization import (dataframe_hash, load_from_file,
                                           save_to_file)

log.remove()

out_dir = Path("workspace_rebuttal")
methods = ["survival_gan", "ctgan", "nflow", "tvae", "privbayes", "adsgan"]

headers = ["dataset"] + methods

for ref_df in ["metabric"]:
    results[ref_df] = {}

    print("=======================")
    print("Evaluate ", ref_df)

    df, duration_col, event_col, time_horizons = get_dataset(ref_df)
    df_hash = dataframe_hash(df)

    real_dataloader = SurvivalAnalysisDataLoader(
        df,
        time_to_event_column=duration_col,
        target_column=event_col,
        time_horizons=time_horizons,
    )
    local_distance = [ref_df]

    for src_eval in [
        PerformanceEvaluatorMLP,
        PerformanceEvaluatorXGB,
        PerformanceEvaluatorLinear,
    ]:
        results[ref_df][src_eval.name()] = {
            "gt": {
                "c_index": [],
                "brier_score": [],
            }
        }
        for method in methods:
            results[ref_df][src_eval.name()][method] = {
                "c_index": [],
                "brier_score": [],
            }
            for seed in range(3):
                model_bkp = out_dir / f"{df_hash}_{method}_{method}__{seed}.bkp"
                syn_df = load_from_file(model_bkp)
                try:
                    syn_df = syn_df.dataframe()
                except BaseException as e:
                    pass

                syn_dataloader = SurvivalAnalysisDataLoader(
                    syn_df,
                    time_to_event_column=duration_col,
                    target_column=event_col,
                    time_horizons=time_horizons,
                )
                try:
                    score = src_eval(task_type="survival_analysis").evaluate(
                        real_dataloader, syn_dataloader
                    )
                except:
                    continue
                print(ref_df, src_eval.name(), method, seed, score)
                results[ref_df][src_eval.name()]["gt"]["c_index"] = score["gt.c_index"]
                results[ref_df][src_eval.name()]["gt"]["brier_score"] = score[
                    "gt.brier_score"
                ]
                results[ref_df][src_eval.name()][method]["c_index"].append(
                    score["syn_id.c_index"]
                )
                results[ref_df][src_eval.name()][method]["brier_score"].append(
                    score["syn_id.brier_score"]
                )
# Out:
# =======================
# Evaluate  metabric
# metabric mlp survival_gan 0 {'gt.c_index': 0.6341500002733197, 'gt.brier_score': 0.17096242975213496, 'syn_id.c_index': 0.6652024503200676, 'syn_id.brier_score': 0.17794654775701013, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric mlp survival_gan 1 {'gt.c_index': 0.6341500002733197, 'gt.brier_score': 0.17096242975213496, 'syn_id.c_index': 0.5963303172720473, 'syn_id.brier_score': 0.18972298382369654, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric mlp survival_gan 2 {'gt.c_index': 0.6341500002733197, 'gt.brier_score': 0.17096242975213496, 'syn_id.c_index': 0.5765371676049208, 'syn_id.brier_score': 0.17498457365085787, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric mlp ctgan 0 {'gt.c_index': 0.6341500002733197, 'gt.brier_score': 0.17096242975213496, 'syn_id.c_index': 0.5827398561563402, 'syn_id.brier_score': 0.17423682934493914, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric mlp ctgan 1 {'gt.c_index': 0.6341500002733197, 'gt.brier_score': 0.17096242975213496, 'syn_id.c_index': 0.5425249573056433, 'syn_id.brier_score': 0.17784749516308054, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric mlp ctgan 2 {'gt.c_index': 0.6341500002733197, 'gt.brier_score': 0.17096242975213496, 'syn_id.c_index': 0.5530986337908477, 'syn_id.brier_score': 0.17582925598044566, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric mlp nflow 0 {'gt.c_index': 0.6341500002733197, 'gt.brier_score': 0.17096242975213496, 'syn_id.c_index': 0.5386859157603522, 'syn_id.brier_score': 0.17328682884926472, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric mlp nflow 1 {'gt.c_index': 0.6341500002733197, 'gt.brier_score': 0.17096242975213496, 'syn_id.c_index': 0.541901582180123, 'syn_id.brier_score': 0.17621204565027573, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric mlp nflow 2 {'gt.c_index': 0.6341500002733197, 'gt.brier_score': 0.17096242975213496, 'syn_id.c_index': 0.4815918646939168, 'syn_id.brier_score': 0.1793835158434155, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric mlp tvae 0 {'gt.c_index': 0.6341500002733197, 'gt.brier_score': 0.17096242975213496, 'syn_id.c_index': 0.6676377845405113, 'syn_id.brier_score': 0.18662559100457743, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric mlp tvae 1 {'gt.c_index': 0.6341500002733197, 'gt.brier_score': 0.17096242975213496, 'syn_id.c_index': 0.6436366375265634, 'syn_id.brier_score': 0.18012541559616543, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric mlp tvae 2 {'gt.c_index': 0.6341500002733197, 'gt.brier_score': 0.17096242975213496, 'syn_id.c_index': 0.6653426881731852, 'syn_id.brier_score': 0.21487914607252342, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric mlp privbayes 0 {'gt.c_index': 0.6341500002733197, 'gt.brier_score': 0.17096242975213496, 'syn_id.c_index': 0.0, 'syn_id.brier_score': 1.0, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric mlp privbayes 1 {'gt.c_index': 0.6341500002733197, 'gt.brier_score': 0.17096242975213496, 'syn_id.c_index': 0.5610387464365836, 'syn_id.brier_score': 0.17638009562722798, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric mlp privbayes 2 {'gt.c_index': 0.6341500002733197, 'gt.brier_score': 0.17096242975213496, 'syn_id.c_index': 0.0, 'syn_id.brier_score': 1.0, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric mlp adsgan 0 {'gt.c_index': 0.6341500002733197, 'gt.brier_score': 0.17096242975213496, 'syn_id.c_index': 0.5431652141034405, 'syn_id.brier_score': 0.3135761886986794, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric mlp adsgan 1 {'gt.c_index': 0.6341500002733197, 'gt.brier_score': 0.17096242975213496, 'syn_id.c_index': 0.559028007148259, 'syn_id.brier_score': 0.22280881345601747, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric mlp adsgan 2 {'gt.c_index': 0.6341500002733197, 'gt.brier_score': 0.17096242975213496, 'syn_id.c_index': 0.5609226851019417, 'syn_id.brier_score': 0.20333063476858468, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric xgb survival_gan 0 {'gt.c_index': 0.7308020170901822, 'gt.brier_score': 0.1626383791816738, 'syn_id.c_index': 0.7263334229725338, 'syn_id.brier_score': 0.2036048402475573, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric xgb survival_gan 1 {'gt.c_index': 0.7308020170901822, 'gt.brier_score': 0.1626383791816738, 'syn_id.c_index': 0.6952665562132069, 'syn_id.brier_score': 0.205401564864637, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric xgb survival_gan 2 {'gt.c_index': 0.7308020170901822, 'gt.brier_score': 0.1626383791816738, 'syn_id.c_index': 0.7234712214064575, 'syn_id.brier_score': 0.20716365455453511, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric xgb ctgan 0 {'gt.c_index': 0.7308020170901822, 'gt.brier_score': 0.1626383791816738, 'syn_id.c_index': 0.5418688388175495, 'syn_id.brier_score': 0.1796872376694317, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric xgb ctgan 1 {'gt.c_index': 0.7308020170901822, 'gt.brier_score': 0.1626383791816738, 'syn_id.c_index': 0.6134758324363089, 'syn_id.brier_score': 0.17529017388814447, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric xgb ctgan 2 {'gt.c_index': 0.7308020170901822, 'gt.brier_score': 0.1626383791816738, 'syn_id.c_index': 0.584314689895974, 'syn_id.brier_score': 0.2047354504317791, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric xgb nflow 0 {'gt.c_index': 0.7308020170901822, 'gt.brier_score': 0.1626383791816738, 'syn_id.c_index': 0.4616983373034646, 'syn_id.brier_score': 0.17021047395774266, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric xgb nflow 1 {'gt.c_index': 0.7308020170901822, 'gt.brier_score': 0.1626383791816738, 'syn_id.c_index': 0.4594875303589873, 'syn_id.brier_score': 0.1768138409241153, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric xgb nflow 2 {'gt.c_index': 0.7308020170901822, 'gt.brier_score': 0.1626383791816738, 'syn_id.c_index': 0.5201006948691909, 'syn_id.brier_score': 0.17768982224680294, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric xgb tvae 0 {'gt.c_index': 0.7308020170901822, 'gt.brier_score': 0.1626383791816738, 'syn_id.c_index': 0.7171630559708317, 'syn_id.brier_score': 0.1639241978645631, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric xgb tvae 1 {'gt.c_index': 0.7308020170901822, 'gt.brier_score': 0.1626383791816738, 'syn_id.c_index': 0.6819868281018574, 'syn_id.brier_score': 0.167928520798334, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric xgb tvae 2 {'gt.c_index': 0.7308020170901822, 'gt.brier_score': 0.1626383791816738, 'syn_id.c_index': 0.6994574779672685, 'syn_id.brier_score': 0.1690417281702669, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric xgb privbayes 0 {'gt.c_index': 0.7308020170901822, 'gt.brier_score': 0.1626383791816738, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.4031618696292454, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric xgb privbayes 1 {'gt.c_index': 0.7308020170901822, 'gt.brier_score': 0.1626383791816738, 'syn_id.c_index': 0.4686983676541085, 'syn_id.brier_score': 0.2592229485593262, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric xgb privbayes 2 {'gt.c_index': 0.7308020170901822, 'gt.brier_score': 0.1626383791816738, 'syn_id.c_index': 0.5, 'syn_id.brier_score': 0.4031618696292454, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric xgb adsgan 0 {'gt.c_index': 0.7308020170901822, 'gt.brier_score': 0.1626383791816738, 'syn_id.c_index': 0.5432990154144306, 'syn_id.brier_score': 0.20541491031676093, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric xgb adsgan 1 {'gt.c_index': 0.7308020170901822, 'gt.brier_score': 0.1626383791816738, 'syn_id.c_index': 0.5524145545581877, 'syn_id.brier_score': 0.2760224857331103, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}
# metabric xgb adsgan 2 {'gt.c_index': 0.7308020170901822, 'gt.brier_score': 0.1626383791816738, 'syn_id.c_index': 0.519616914431489, 'syn_id.brier_score': 0.29716818289163965, 'syn_ood.c_index': 0.0, 'syn_ood.brier_score': 1.0}

# %%
results
# Out:
# {'aids': {'mlp': {'gt': {'c_index': 0.7059304149697022,
#     'brier_score': 0.06806232093352434},
#    'survival_gan': {'c_index': [0.6454852592877075,
#      0.7165071752721839,
#      0.7644641382612013],
#     'brier_score': [0.07742694851561303,
#      0.07776424405215514,
#      0.07990441130531196]},
#    'ctgan': {'c_index': [0.0, 0.520568649905171, 0.5542162720615037],
#     'brier_score': [1.0, 0.07613622330571594, 0.10876656241751877]},
#    'nflow': {'c_index': [0.3836290426816391,
#      0.37855223712306135,
#      0.5309118212646274],
#     'brier_score': [0.1360939367406394,
#      0.16071780684920026,
#      0.1273532349081433]},
#    'tvae': {'c_index': [0.0, 0.4973162193929452, 0.0],
#     'brier_score': [1.0, 0.07745913854287934, 1.0]},
#    'privbayes': {'c_index': [0.47586271354782933,
#      0.4173548020659998,
#      0.2991700915100185],
#     'brier_score': [0.07847409831109108,
#      0.09323820812133977,
#      0.07883306714479758]},
#    'adsgan': {'c_index': [0.0, 0.5985419306860772, 0.0],
#     'brier_score': [1.0, 0.07675083822459335, 1.0]}},
#   'xgb': {'gt': {'c_index': 0.7356953628118555,
#     'brier_score': 0.062788404425297},
#    'survival_gan': {'c_index': [0.5742303039522929,
#      0.7854100648404208,
#      0.7085975400715928],
#     'brier_score': [0.07134156171436111,
#      0.06900873680903102,
#      0.06915268699578814]},
#    'ctgan': {'c_index': [0.6822746913277724,
#      0.4987423458317919,
#      0.7374737093767485],
#     'brier_score': [0.0721676595982021,
#      0.07289199673517642,
#      0.07400613390613633]},
#    'nflow': {'c_index': [0.46994320089725,
#      0.594376683161613,
#      0.44862952170621034],
#     'brier_score': [0.09653666803379451,
#      0.14253265702892295,
#      0.09818776283163667]},
#    'tvae': {'c_index': [0.5, 0.6885742237330555, 0.5],
#     'brier_score': [0.07746034739915574,
#      0.0773043198558032,
#      0.0773128618326687]},
#    'privbayes': {'c_index': [0.5888151534188154,
#      0.4782561856210427,
#      0.5732327893991209],
#     'brier_score': [0.0752125027563393,
#      0.07169927381484396,
#      0.07228436595620757]},
#    'adsgan': {'c_index': [0.5, 0.6940310329823038, 0.5],
#     'brier_score': [0.07746034739915574,
#      0.0727556481660794,
#      0.07746034739915574]}},
#   'linear_model': {'gt': {'c_index': 0.7376085764258152,
#     'brier_score': 0.061707863206065416},
#    'survival_gan': {'c_index': [0.0, 0.0, 0.0],
#     'brier_score': [1.0, 1.0, 1.0]},
#    'ctgan': {'c_index': [0.6949089269268556,
#      0.45723162100221026,
#      0.7866488639578796],
#     'brier_score': [0.0711931786732762,
#      0.07391699898006086,
#      0.06988575971496876]},
#    'nflow': {'c_index': [0.5648951840565446,
#      0.48358208181378104,
#      0.46960948352234677],
#     'brier_score': [0.0913250877813039,
#      0.12747251100036605,
#      0.11552923188934193]},
#    'tvae': {'c_index': [0.0, 0.5136704390235118, 0.49570821101240287],
#     'brier_score': [1.0, 0.09986260268150948, 0.10206638969837839]},
#    'privbayes': {'c_index': [0.5756952632093969,
#      0.5276712033890112,
#      0.5092327753601479],
#     'brier_score': [0.0744624317655898,
#      0.07174982366218323,
#      0.07360596121188029]},
#    'adsgan': {'c_index': [0.0, 0.5181922792673933, 0.0],
#     'brier_score': [1.0, 0.174300646655429, 1.0]}}},
#  'cutract': {'mlp': {'gt': {'c_index': 0.7227856874466392,
#     'brier_score': 0.09078878664723468},
#    'survival_gan': {'c_index': [0.6773662560026695,
#      0.7745746052534509,
#      0.7781613895561756],
#     'brier_score': [0.09294071269302889,
#      0.08433732524161704,
#      0.10017100712450633]},
#    'ctgan': {'c_index': [0.7553184846865162,
#      0.6777539893172868,
#      0.7390306737034017],
#     'brier_score': [0.1849173173231573,
#      0.23579553681046647,
#      0.18296172823834211]},
#    'nflow': {'c_index': [0.5, 0.5, 0.5],
#     'brier_score': [0.2118141694051856,
#      0.21303283198093467,
#      0.21931965645569998]},
#    'tvae': {'c_index': [0.6672435193952179,
#      0.6501148589004849,
#      0.6103256770969473],
#     'brier_score': [0.13643659037389988,
#      0.1334711128785412,
#      0.16894916327383427]},
#    'privbayes': {'c_index': [0.5011914114529299, 0.5, 0.4985786034674285],
#     'brier_score': [0.09919928763334858,
#      0.09969794997165378,
#      0.0995445068894776]},
#    'adsgan': {'c_index': [0.6219788013585114, 0.0, 0.5566569436601775],
#     'brier_score': [0.11203897652360846, 1.0, 0.10351229775096223]}},
#   'xgb': {'gt': {'c_index': 0.8319374581013449,
#     'brier_score': 0.08457689286909124},
#    'survival_gan': {'c_index': [0.7741866546777638,
#      0.7804397937915969,
#      0.7746854689867586],
#     'brier_score': [0.08556463616200416,
#      0.08799037954154254,
#      0.0857674646153521]},
#    'ctgan': {'c_index': [0.7695774796569266,
#      0.775619153193384,
#      0.7781166464936881],
#     'brier_score': [0.19355249482568615,
#      0.2291775444741634,
#      0.2019013182753212]},
#    'nflow': {'c_index': [0.6836882506780282,
#      0.5049244070795614,
#      0.5166486927515807],
#     'brier_score': [0.19911975079772234,
#      0.2131364511566044,
#      0.21327164845258859]},
#    'tvae': {'c_index': [0.7186431662866388,
#      0.7422151554796939,
#      0.7627922954211982],
#     'brier_score': [0.09965156765209891,
#      0.09820782415698236,
#      0.09525052497309039]},
#    'privbayes': {'c_index': [0.4845736296490728,
#      0.4075450577243777,
#      0.586645728190701],
#     'brier_score': [0.09933357859454749,
#      0.10075102540197052,
#      0.09879764689271786]},
#    'adsgan': {'c_index': [0.711142646483426, 0.5, 0.587557517681081],
#     'brier_score': [0.11389588655609607,
#      0.11468457957758581,
#      0.11116755994790765]}},
#   'linear_model': {'gt': {'c_index': 0.8098309079742018,
#     'brier_score': 0.07536036182071539},
#    'survival_gan': {'c_index': [0.7626953767923544,
#      0.7568697049687904,
#      0.7687297248123496],
#     'brier_score': [0.08435359446666808,
#      0.0870116494443915,
#      0.10819228259054055]},
#    'ctgan': {'c_index': [0.7586253153808049,
#      0.7676091861839117,
#      0.7680070547371444],
#     'brier_score': [0.1686652101277557,
#      0.21098839351746976,
#      0.17083589343851488]},
#    'nflow': {'c_index': [0.7246664538005613,
#      0.5830555439090589,
#      0.6586605983597654],
#     'brier_score': [0.19298591661162987,
#      0.19398797773963763,
#      0.21662508718053938]},
#    'tvae': {'c_index': [0.7647022446718711,
#      0.7500175950992182,
#      0.7730655791592701],
#     'brier_score': [0.10632582258976275,
#      0.10316631787731234,
#      0.09992020036853022]},
#    'privbayes': {'c_index': [0.48398111402388005,
#      0.33731524870343793,
#      0.46263432096907015],
#     'brier_score': [0.0994239958937826,
#      0.10190681977567288,
#      0.0996153281745405]},
#    'adsgan': {'c_index': [0.7233637838538503, 0.0, 0.3924229936801327],
#     'brier_score': [0.11152711481069337, 1.0, 0.11896602051966236]}}},
#  'maggic': {'mlp': {'gt': {'c_index': 0.6351989261191153,
#     'brier_score': 0.1679785580062451},
#    'survival_gan': {'c_index': [0.5451663572193332,
#      0.6132180676114923,
#      0.6407541317291121],
#     'brier_score': [0.1847187674345568,
#      0.1838610067650488,
#      0.17898222405093908]},
#    'ctgan': {'c_index': [0.4997565094398053,
#      0.5004247032471466,
#      0.49892071942860367],
#     'brier_score': [0.20289603605986942,
#      0.19245772797563043,
#      0.19649597639613162]},
#    'nflow': {'c_index': [0.5, 0.5, 0.5],
#     'brier_score': [0.19279772197451106,
#      0.1905426105930417,
#      0.1940005379882294]},
#    'tvae': {'c_index': [0.5413940319523554,
#      0.5536179448335039,
#      0.5356216133258178],
#     'brier_score': [0.2210225085691858,
#      0.21255836419563423,
#      0.21067922115545704]},
#    'privbayes': {'c_index': [0.5, 0.5, 0.5],
#     'brier_score': [0.21609710425173811,
#      0.20754231534156667,
#      0.20696313974108368]},
#    'adsgan': {'c_index': [0.5049834223015863,
#      0.5334826640220739,
#      0.5105364847317403],
#     'brier_score': [0.22621436388118185,
#      0.23016003082697867,
#      0.24244769043557493]}},
#   'xgb': {'gt': {'c_index': 0.6654334315503624,
#     'brier_score': 0.15120604857477493},
#    'survival_gan': {'c_index': [0.6347711754571775,
#      0.5774669041777848,
#      0.6252707348144699],
#     'brier_score': [0.17898369974451991,
#      0.19151403324599658,
#      0.180402368625159]},
#    'ctgan': {'c_index': [0.5828279669020512,
#      0.6064588205023541,
#      0.6137101246463434],
#     'brier_score': [0.1994609822930423,
#      0.184975819498722,
#      0.18264759072299616]},
#    'nflow': {'c_index': [0.562636851349216,
#      0.5492959840364038,
#      0.568437746527732],
#     'brier_score': [0.1954347983895562,
#      0.20770980457147925,
#      0.1728822538128839]},
#    'tvae': {'c_index': [0.594482553410501,
#      0.6291677646517456,
#      0.6421990908810774],
#     'brier_score': [0.20604006071015424,
#      0.1975788509127702,
#      0.22105759327378308]},
#    'privbayes': {'c_index': [0.5535910604530823,
#      0.5702533702912341,
#      0.5463853767055479],
#     'brier_score': [0.21348680180120702,
#      0.2018138326918879,
#      0.206219772478658]},
#    'adsgan': {'c_index': [0.5792621553530561,
#      0.5806771273260792,
#      0.5139560152795964],
#     'brier_score': [0.35801207436553883,
#      0.19855326672934534,
#      0.20912624217418072]}},
#   'linear_model': {'gt': {'c_index': 0.6632499286175375,
#     'brier_score': 0.14648157483114163},
#    'survival_gan': {'c_index': [0.6506400145488697,
#      0.6331425725797539,
#      0.642070835841678],
#     'brier_score': [0.45038374747411036,
#      0.17775060811270915,
#      0.1831008961403139]},
#    'ctgan': {'c_index': [0.6148440120262184,
#      0.6134155706654828,
#      0.5821084466200495],
#     'brier_score': [0.44618053533735985,
#      0.440438276154363,
#      0.434120819361777]},
#    'nflow': {'c_index': [0.5780066460409303,
#      0.565385916370452,
#      0.5471859843696462],
#     'brier_score': [0.19308680792690755,
#      0.21315559006124238,
#      0.19891711725674557]},
#    'tvae': {'c_index': [0.5492515057616242,
#      0.6270972107114413,
#      0.5911000418925705],
#     'brier_score': [0.5195589466359359,
#      0.46210329204622763,
#      0.4717002768271124]},
#    'privbayes': {'c_index': [0.5669192792327395,
#      0.5765792991544975,
#      0.5810228644189331],
#     'brier_score': [0.213672207236382,
#      0.20425301654785236,
#      0.2059217558411031]},
#    'adsgan': {'c_index': [0.5361804823186805,
#      0.5659152787427425,
#      0.48261815678795017],
#     'brier_score': [0.6876754348272368,
#      0.48223452209200107,
#      0.5429256761898683]}}},
#  'seer': {'mlp': {'gt': {'c_index': 0.5000004041745689,
#     'brier_score': 0.02412814886111232},
#    'survival_gan': {'c_index': [0.5, 0.5, 0.5001266850867621],
#     'brier_score': [0.025576156578280145,
#      0.02413232719705384,
#      0.03877040837008744]},
#    'ctgan': {'c_index': [0.5, 0.7212235243483769, 0.7742860676152183],
#     'brier_score': [0.15493806825413384,
#      0.2412876251711149,
#      0.1847031397988701]},
#    'nflow': {'c_index': [0.5, 0.5, 0.5],
#     'brier_score': [0.3175816236816999,
#      0.17831593041104574,
#      0.1139921561537323]},
#    'tvae': {'c_index': [0.5391989675216394,
#      0.5311094603699845,
#      0.5320247579423274],
#     'brier_score': [0.024857947658304624,
#      0.024851865199464734,
#      0.024811511332274102]},
#    'privbayes': {'c_index': [0.5, 0.5, 0.5],
#     'brier_score': [0.024142282606263322,
#      0.024133100040983953,
#      0.024156118166323667]},
#    'adsgan': {'c_index': [0.0, 0.0, 0.0], 'brier_score': [1.0, 1.0, 1.0]}},
#   'xgb': {'gt': {'c_index': 0.8521464322079112,
#     'brier_score': 0.021661690647627116},
#    'survival_gan': {'c_index': [0.8300345303723828,
#      0.8320651460589995,
#      0.6941620434764183],
#     'brier_score': [0.021844831261625754,
#      0.022478355436141472,
#      0.02400423089554961]},
#    'ctgan': {'c_index': [0.8109349198135041,
#      0.8089782055852961,
#      0.773468076143976],
#     'brier_score': [0.0840426414404048,
#      0.16606136715538097,
#      0.15353432936427258]},
#    'nflow': {'c_index': [0.5875724979038363,
#      0.5940389090755374,
#      0.6889375355120769],
#     'brier_score': [0.25119403036887683,
#      0.15878259787838614,
#      0.07560516089413029]},
#    'tvae': {'c_index': [0.8359323272073681,
#      0.7806821933822493,
#      0.8122737228861222],
#     'brier_score': [0.023998900075255004,
#      0.02482901813637536,
#      0.024503811779296558]},
#    'privbayes': {'c_index': [0.3889121899194545,
#      0.5248054074908431,
#      0.3928798820789276],
#     'brier_score': [0.024151075100059465,
#      0.02414781016591738,
#      0.02416185866335067]},
#    'adsgan': {'c_index': [0.5, 0.5, 0.5],
#     'brier_score': [0.024896275616259202,
#      0.024896275616259202,
#      0.024896275616259202]}},
#   'linear_model': {'gt': {'c_index': 0.8478194755263354,
#     'brier_score': 0.020776657214431535},
#    'survival_gan': {'c_index': [0.8462229709304018,
#      0.8286079327437789,
#      0.8231901100413107],
#     'brier_score': [0.021506527394729944,
#      0.02144260306350441,
#      0.02856377118884193]},
#    'ctgan': {'c_index': [0.839219164165527,
#      0.85242590701232,
#      0.8229119745696541],
#     'brier_score': [0.07670902991276568,
#      0.17020673154068353,
#      0.15579968249278145]},
#    'nflow': {'c_index': [0.8054196286303469,
#      0.8149448709121758,
#      0.7313478770791227],
#     'brier_score': [0.3029290575348027,
#      0.15834672995370244,
#      0.09040636952763342]},
#    'tvae': {'c_index': [0.7502292432639358,
#      0.6487184389598107,
#      0.7691756705464318],
#     'brier_score': [0.023878950787843255,
#      0.02428149058222241,
#      0.02380662817985475]},
#    'privbayes': {'c_index': [0.2604718500733248,
#      0.7388288322401664,
#      0.4928148139874826],
#     'brier_score': [0.024160349335648035,
#      0.0240703519782143,
#      0.024122150942609413]},
#    'adsgan': {'c_index': [0.0, 0.0, 0.0], 'brier_score': [1.0, 1.0, 1.0]}}},
#  'metabric': {'mlp': {'gt': {'c_index': 0.6341500002733197,
#     'brier_score': 0.17096242975213496},
#    'survival_gan': {'c_index': [0.6652024503200676,
#      0.5963303172720473,
#      0.5765371676049208],
#     'brier_score': [0.17794654775701013,
#      0.18972298382369654,
#      0.17498457365085787]},
#    'ctgan': {'c_index': [0.5827398561563402,
#      0.5425249573056433,
#      0.5530986337908477],
#     'brier_score': [0.17423682934493914,
#      0.17784749516308054,
#      0.17582925598044566]},
#    'nflow': {'c_index': [0.5386859157603522,
#      0.541901582180123,
#      0.4815918646939168],
#     'brier_score': [0.17328682884926472,
#      0.17621204565027573,
#      0.1793835158434155]},
#    'tvae': {'c_index': [0.6676377845405113,
#      0.6436366375265634,
#      0.6653426881731852],
#     'brier_score': [0.18662559100457743,
#      0.18012541559616543,
#      0.21487914607252342]},
#    'privbayes': {'c_index': [0.0, 0.5610387464365836, 0.0],
#     'brier_score': [1.0, 0.17638009562722798, 1.0]},
#    'adsgan': {'c_index': [0.5431652141034405,
#      0.559028007148259,
#      0.5609226851019417],
#     'brier_score': [0.3135761886986794,
#      0.22280881345601747,
#      0.20333063476858468]}},
#   'xgb': {'gt': {'c_index': 0.7308020170901822,
#     'brier_score': 0.1626383791816738},
#    'survival_gan': {'c_index': [0.7263334229725338,
#      0.6952665562132069,
#      0.7234712214064575],
#     'brier_score': [0.2036048402475573,
#      0.205401564864637,
#      0.20716365455453511]},
#    'ctgan': {'c_index': [0.5418688388175495,
#      0.6134758324363089,
#      0.584314689895974],
#     'brier_score': [0.1796872376694317,
#      0.17529017388814447,
#      0.2047354504317791]},
#    'nflow': {'c_index': [0.4616983373034646,
#      0.4594875303589873,
#      0.5201006948691909],
#     'brier_score': [0.17021047395774266,
#      0.1768138409241153,
#      0.17768982224680294]},
#    'tvae': {'c_index': [0.7171630559708317,
#      0.6819868281018574,
#      0.6994574779672685],
#     'brier_score': [0.1639241978645631,
#      0.167928520798334,
#      0.1690417281702669]},
#    'privbayes': {'c_index': [0.5, 0.4686983676541085, 0.5],
#     'brier_score': [0.4031618696292454,
#      0.2592229485593262,
#      0.4031618696292454]},
#    'adsgan': {'c_index': [0.5432990154144306,
#      0.5524145545581877,
#      0.519616914431489],
#     'brier_score': [0.20541491031676093,
#      0.2760224857331103,
#      0.29716818289163965]}},
#   'linear_model': {'gt': {'c_index': [], 'brier_score': []},
#    'survival_gan': {'c_index': [], 'brier_score': []},
#    'ctgan': {'c_index': [], 'brier_score': []},
#    'nflow': {'c_index': [], 'brier_score': []},
#    'tvae': {'c_index': [], 'brier_score': []},
#    'privbayes': {'c_index': [], 'brier_score': []},
#    'adsgan': {'c_index': [], 'brier_score': []}}}}
